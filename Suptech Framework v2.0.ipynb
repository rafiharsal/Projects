# %% [markdown]
# # Suptech Framework Detection of Illegal Payment System Service Provider App in Indonesia Listed in Google PlayStore
#
# [By: Rafi Salman](https://www.linkedin.com/in/rafisalman/)

# %% [markdown]
# ### Scrape payment related app from Google Play Store using google_play_scraper
#
# First we need to obtain list of apps that are related with payment in google play store that available for download in Indonesia

# %%
import pandas as pd
import yake
from google_play_scraper import search
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %%
def crawled_ps(search_keyword):
    playstore = pd.DataFrame()
    for keyword in search_keyword:
        result = search(
                keyword,
                lang="en",  # Majority of apps have default desc in English (en)
                country="id",  # Available for download in Indonesia (id)'
                n_hits=30 # defaults to 30 (= Google's maximum)
)          
        if len(playstore.index) == 0:
            playstore = pd.DataFrame(result)
        else:
            more_apps = pd.DataFrame(result)
            playstore = pd.concat([playstore, more_apps], ignore_index=True)
    return playstore

# %%
search_keyword = ['wallet', 'dompet digital']

# %%
# Store the dataset in form of dataframe in varible playstore
playstore = crawled_ps(search_keyword)

# %%
# Sample of details of app stored in playstore df
playstore.head()
# Out:
#                               appId  \
# 0  com.droid4you.application.wallet
# 1        com.wallet.crypto.trustapp
# 2                 com.airtm.android
# 3                       io.metamask
# 4                         org.toshi
#
#                                                 icon  \
# 0  https://play-lh.googleusercontent.com/DqAKT8mJ...
# 1  https://play-lh.googleusercontent.com/-3uTwEsZ...
# 2  https://play-lh.googleusercontent.com/sTc5uAZ8...
# 3  https://play-lh.googleusercontent.com/8rzHJpfk...
# 4  https://play-lh.googleusercontent.com/wrgUujbq...
#
#                                          screenshots  \
# 0  [https://play-lh.googleusercontent.com/7K9xn0C...
# 1  [https://play-lh.googleusercontent.com/HOAibhB...
# 2  [https://play-lh.googleusercontent.com/NSj16yx...
# 3  [https://play-lh.googleusercontent.com/_bBbQOO...
# 4  [https://play-lh.googleusercontent.com/rCqX7hd...
#
#                             title     score    genre  price  free currency  \
# 0  Wallet: Budget Expense Tracker  4.895610  Finance      0  True      IDR
# 1  Trust: Crypto & Bitcoin Wallet  4.705442  Finance      0  True      IDR
# 2                           Airtm  3.800000  Finance      0  True      IDR
# 3    MetaMask - Blockchain Wallet  4.455304  Finance      0  True      IDR
# 4  Coinbase Wallet: NFTs & Crypto  3.178571  Finance      0  True      IDR
#
#                                                video  \
# 0                                               None
# 1                                               None
# 2  https://www.youtube.com/embed/rsN3CTtU_FA?ps=p...
# 3  https://www.youtube.com/embed/YVgfHZMFFFQ?ps=p...
# 4                                               None
#
#                                          videoImage  \
# 0                                              None
# 1                                              None
# 2  https://i.ytimg.com/vi/rsN3CTtU_FA/hqdefault.jpg
# 3  https://i.ytimg.com/vi/YVgfHZMFFFQ/hqdefault.jpg
# 4                                              None
#
#                                          description  \
# 0  <b>Wallet is a market-leading personal finance...
# 1  Trust Wallet is the official crypto wallet of ...
# 2  Access your money when you want, wherever you ...
# 3  Whether you are an experienced user or brand n...
# 4  Coinbase Wallet is your key to what’s next in ...
#
#                                      descriptionHTML             developer  \
# 0  <b>Wallet is a market-leading personal finance...      BudgetBakers.com
# 1  Trust Wallet is the official crypto wallet of ...  DApps Platform, Inc.
# 2  Access your money when you want, wherever you ...           Airtm, Inc.
# 3  Whether you are an experienced user or brand n...  MetaMask Web3 Wallet
# 4  Coinbase Wallet is your key to what’s next in ...       Coinbase Wallet
#
#       installs
# 0   5,000,000+
# 1  10,000,000+
# 2   1,000,000+
# 3  10,000,000+
# 4   5,000,000+

# %%
# Details of the crawled app list, we can see total numbers of entries listed
playstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   appId            58 non-null     object
#  1   icon             58 non-null     object
#  2   screenshots      58 non-null     object
#  3   title            58 non-null     object
#  4   score            58 non-null     float64
#  5   genre            58 non-null     object
#  6   price            58 non-null     int64
#  7   free             58 non-null     bool
#  8   currency         58 non-null     object
#  9   video            22 non-null     object
#  10  videoImage       22 non-null     object
#  11  description      58 non-null     object
#  12  descriptionHTML  58 non-null     object
#  13  developer        58 non-null     object
#  14  installs         58 non-null     object
# dtypes: bool(1), float64(1), int64(1), object(12)
# memory usage: 6.5+ KB

# %% [markdown]
# Since there is possibility that different keyword might return same app, we will remove the duplicated app details

# %%
# Drop duplicated app details
playstore.drop_duplicates(subset="appId", keep='first', inplace=True)

# %%
# Total numbers of entries might decrease due to dropped duplicated entry
playstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53 entries, 0 to 57
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   appId            53 non-null     object
#  1   icon             53 non-null     object
#  2   screenshots      53 non-null     object
#  3   title            53 non-null     object
#  4   score            53 non-null     float64
#  5   genre            53 non-null     object
#  6   price            53 non-null     int64
#  7   free             53 non-null     bool
#  8   currency         53 non-null     object
#  9   video            19 non-null     object
#  10  videoImage       19 non-null     object
#  11  description      53 non-null     object
#  12  descriptionHTML  53 non-null     object
#  13  developer        53 non-null     object
#  14  installs         53 non-null     object
# dtypes: bool(1), float64(1), int64(1), object(12)
# memory usage: 6.3+ KB

# %% [markdown]
# ### Upload List Legal Payment System Service Provider Company Provider Dataset
#
# Next, we upload the list of payment system service provider company listed in Bank Indonesia.
#
# The list can be found [here](https://www.bi.go.id/PJSPQRIS/default.aspx)

# %%
# Upload the list
legal_bi = pd.read_csv('legal_BI.csv')

# %%
# Example of legal PSP on the dataset, the dataframe has gone through preprocessing before uploaded
legal_bi[:5]
# Out:
#                                        organization product  \
# 0        PT Pan Indonesia Bank, Tbk (PT Bank Panin)     NaN
# 1  Lembaga Pelatihan Kerja Alfamart Learning Center     NaN
# 2                           PT Citra Abdi Valasindo     NaN
# 3                         PT Dewata Inter Valasindo     NaN
# 4                          PT Luxury Valuta Perkasa     NaN
#
#                                              address telephone  \
# 0  Gedung Panin Centre Lt. 1-2, Jl. Jend. Sudirma...       NaN
# 1  Alfa Tower Lantai 19, Alamat Sutera, Jl. Jalur...       NaN
# 2  Wisma Bumiputera Lt. 2/M, Jl. Jendral Sudirman...       NaN
# 3  Jl. Bulungan I No. 64, Gedung Ayam Bulungan Lt...       NaN
# 4  Jalan Panglima Polim Raya No. 105, Kel. Melawa...       NaN
#
#                            category         decision_number decision_date  \
# 0                              QRIS       24/303/DKSP/Srt/B      8/8/2022
# 1            Job Training Institute  24/159/DPSP-GESK/Srt/B     7/27/2022
# 2  Non Bank Money Changer Operators  24/37/KEP.PBI/Jkt/2022      7/8/2022
# 3  Non Bank Money Changer Operators  24/39/KEP.PBI/Jkt/2022      7/8/2022
# 4  Non Bank Money Changer Operators  24/40/KEP.PBI/Jkt/2022      7/8/2022
#
#                              permit_place operational_date  \
# 0  Departemen Kebijakan Sistem Pembayaran              NaN
# 1                                 Jakarta              NaN
# 2              KPwBI Provinsi DKI Jakarta        7/11/2022
# 3              KPwBI Provinsi DKI Jakarta        7/18/2022
# 4              KPwBI Provinsi DKI Jakarta        7/12/2022
#
#                         description                         status  \
# 0                    QRIS Operators  Berizin (Belum Beroperasinal)
# 1            Job Training Institute    Berizin (Telah Operasional)
# 2  Non Bank Money Changer Operators    Berizin (Telah Operasional)
# 3  Non Bank Money Changer Operators    Berizin (Telah Operasional)
# 4  Non Bank Money Changer Operators    Berizin (Telah Operasional)
#
#            barcode email website
# 0              NaN   NaN     NaN
# 1              NaN   NaN     NaN
# 2  1424.48-000/Jkt   NaN     NaN
# 3  1423.47-000/Jkt   NaN     NaN
# 4  1422.46-001/Jkt   NaN     NaN

# %% [markdown]
# ### Using NLP Fuzzy String Matching to Match Developer of Each App with Organization Listed in Bank Indonesia
#
# We will use Fuzzywuzzy library for this part and later process that needs matching between list value of datasets.
#
# * Fuzzywuzzy library is a Python library that uses Levenshtein Distance to calculate the differences between sequences in a simple-to-use package.
#
# * We need to use NLP since the company or developer listed on **playstore['developer']** might have slight naming difference than the one listed in the **legal_bi['organization']**. Even though both are the same entity
#
# There are several methods to compare two strings in Fuzzywuzzy, we will test each methods and find the most suited method

# %% [markdown]
# `ratio`, compares the entire string similarity, in order.

# %%
# fuzz.ratio(Playstore[title],list_berizin[nama_penyelenggara])
fuzz.ratio('PT. Sprint Asia Technology', 'PT Sprint Asia Technology')
# Out:
# 98

# %%
fuzz.ratio('PT. Nusa Satu Inti Artha (DOKU)', 'PT Nusa Satu Inti Artha')
# Out:
# 85

# %%
fuzz.ratio('PT.BANK PEMBANGUNAN DAERAH JAWA BARAT & BANTEN,TBK', 'PT Bank Jabar dan Banten')
# Out:
# 24

# %% [markdown]
# **'PT.BANK PEMBANGUNAN DAERAH JAWA BARAT & BANTEN,TBK'** and **'PT Bank Jabar dan Banten'** even though we know that both are the same entity is only 24% the same.
#
# It turns out, the naive approach is far too sensitive to minor differences in word order, missing or extra words, and other such issues.

# %% [markdown]
# Next we use `partial_ratio`, as it compares partial string similarity using the same data pairs

# %%
# fuzz.partial_ratio(Playstore[title],list_berizin[nama_penyelenggara])
fuzz.partial_ratio('PT. Sprint Asia Technology', 'PT Sprint Asia Technology')
# Out:
# 96

# %%
fuzz.partial_ratio('PT. Nusa Satu Inti Artha (DOKU)', 'PT Nusa Satu Inti Artha')
# Out:
# 96

# %%
fuzz.partial_ratio('PT.BANK PEMBANGUNAN DAERAH JAWA BARAT & BANTEN,TBK', 'PT Bank Jabar dan Banten')
# Out:
# 21

# %% [markdown]
# For this data set, comparing partial string while it does bring better score for one result, but it's not the same case with the others.
#
# The next method is `token_sort_ratio`, token_sort_ratio will ignores word order.

# %%
# fuzz.token_sort_ratio(Playstore[title],list_berizin[nama_penyelenggara])
fuzz.token_sort_ratio('PT. Sprint Asia Technology', 'PT Sprint Asia Technology')
# Out:
# 100

# %%
fuzz.token_sort_ratio('PT. Nusa Satu Inti Artha (DOKU)', 'PT Nusa Satu Inti Artha')
# Out:
# 90

# %%
fuzz.token_sort_ratio('PT.BANK PEMBANGUNAN DAERAH JAWA BARAT & BANTEN,TBK', 'PT Bank Jabar dan Banten')
# Out:
# 61

# %% [markdown]
# This method has the best result so far, we take look at the final method.
#
# `token_set_ratio`, it will ignores duplicated words. It is similar with token sort ratio, but a little bit more flexible.`

# %%
# fuzz.token_set_ratio(Playstore[title],list_berizin[nama_penyelenggara])
fuzz.token_set_ratio('PT. Sprint Asia Technology', 'PT Sprint Asia Technology')
# Out:
# 100

# %%
fuzz.token_set_ratio('PT. Nusa Satu Inti Artha (DOKU)', 'PT Nusa Satu Inti Artha')
# Out:
# 100

# %%
fuzz.token_set_ratio('PT.BANK PEMBANGUNAN DAERAH JAWA BARAT & BANTEN,TBK', 'PT Bank Jabar dan Banten')
# Out:
# 74

# %% [markdown]
# Looks like `token_set_ratio` is the best fit for our dataset. According to this discovery, we decided to apply token_set_ratio for the developer/organization matching.
#
# We will then create a function that will do matching and return two list for each of the listed and unlisted list of app's parameter (developer, title, etc).
#
# * The default parameter of the function based on the testing above will be `token_set_ratio`
# * And the minimum ratio score will be **70** to be recognized as the same value/entity

# %%
def check_listed(match_list, source_list, unlisted_list, listed_list, method=fuzz.token_set_ratio, ratio_score=74):
    for name in match_list:
        result = process.extractOne(name, source_list, scorer=method)
        ratio = int(result[1])
        if ratio <= ratio_score:
            unlisted_list.append(name)
        else:
            listed_list.append(name)

# %% [markdown]
# ### Checking if the developer company is listed on the legal_PSP list

# %%
# First We Will create a new dataframe for the crawled playstore dataset to keep the original safe
result_df = playstore[['title', 'developer', 'description', 'installs']].copy()

# We wil only select few relevant column that we can use for later analysis

# %%
unlisted_developer = []
listed_developer = []

# Call check_listed function on developer name
check_listed(result_df['developer'], 
             legal_bi['organization'], 
             unlisted_developer, 
             listed_developer
            )

# %% [markdown]
# #### Program to manually check ratio between matched value
# for name in result_df['developer']:
#         result = process.extractOne(name, legal_bi['organization'], scorer=fuzz.token_set_ratio)
#         ratio = int(result[1])
#         if ratio <= 74:
#             None
#         else:
#             print(name, result)

# %%
# Sample name of unlisted developer from crawled dataset in Bank Indonesia
unlisted_developer[:10]
# Out:
# ['BudgetBakers.com',
#  'DApps Platform, Inc.',
#  'Airtm, Inc.',
#  'MetaMask Web3 Wallet',
#  'Coinbase Wallet',
#  'WEMIX PTE. LTD.',
#  'BitKeep Global Inc',
#  'Hellenic Republic',
#  'Wallet Cards Alliance',
#  'Exodus Movement, Inc.']

# %%
# Sample name of listed developer from crawled dataset in Bank Indonesia
listed_developer[:10]
# Out:
# ['PT Espay Debit Indonesia Koe',
#  'PT. Nusa Satu Inti Artha (DOKU)',
#  'PT Fintek Karya Nusantara',
#  'PT Visionet Internasional',
#  'PT Fliptech Lentera Inspirasi Pertiwi',
#  'Inti Dunia Sukses, PT',
#  'Dwijaya Mandiri Sejahtera Indonesia',
#  'ALFA TECHNOLOGY',
#  'PayoApp Indonesia',
#  'PT Visionet Internasional']

# %% [markdown]
# We will then create a new column for this result where developer listed in listed_bi['organization'] will be set as True

# %%
# Create new column named 'dev_status' where listed developer's app will have True value
result_df['dev_status'] = result_df['developer'].isin(listed_developer)

# %%
# Current state of our result_df dataframe where if dev_status = false means the developer for each of the app is not 
# a listed organization in the legal_psp dataset
result_df
# Out:
#                              title  \
# 0   Wallet: Budget Expense Tracker
# 1   Trust: Crypto & Bitcoin Wallet
# 2                            Airtm
# 3     MetaMask - Blockchain Wallet
# 4   Coinbase Wallet: NFTs & Crypto
# 5    DANA Indonesia Digital Wallet
# 6                             DOKU
# 7                     WEMIX Wallet
# 8      BitKeep: Crypto DeFi Wallet
# 9                    Gov.gr Wallet
# 10   Wallet Cards | Digital Wallet
# 11       LinkAja / LinkAja Syariah
# 12   Exodus: Crypto Bitcoin Wallet
# 13  TokenPocket Wallet Crypto DeFi
# 14  Blockchain.com Wallet: Buy BTC
# 15                Pera Algo Wallet
# 16  WalletPasses | Passbook Wallet
# 17  Coinomi: Crypto Bitcoin Wallet
# 18  IME Pay- Mobile Digital Wallet
# 19  SafePal-Crypto wallet BTC NFTs
# 20  ONE Wallet - Empty your wallet
# 21           Cards - Mobile Wallet
# 22                    Jeton Wallet
# 23        Solflare - Solana Wallet
# 24    Klever: Secure Crypto Wallet
# 25       BlueWallet Bitcoin Wallet
# 26        Crypto.com l DeFi Wallet
# 27    MEW wallet – Ethereum wallet
# 28  Bitcoin Wallet: BTC, ETH & BCH
# 29  Fearless Wallet: Polkadot, クサマ
# 31                             OVO
# 33    Flip: Transfer Without Admin
# 35                          i.saku
# 36                         STICPAY
# 39                  Dompet Digital
# 40              DAS Dompet Digital
# 41         Uncang - Dompet Digital
# 42                    OVO Merchant
# 43                          Sakuku
# 44                       BRImo BRI
# 45                           Dipay
# 46        Cek Saldo Dompet Digital
# 47                        E-Wallet
# 48              blu by BCA Digital
# 49                          NETZME
# 50       neobank: BNC digital bank
# 51                       Allo Bank
# 52  PAYFAZZ Agen: Pulsa & Transfer
# 53                       yourpayID
# 54                  Dompet Manfaat
# 55                      MPM Wallet
# 56                         SeaBank
# 57                  Dompet Mandiri
#
#                                          developer  \
# 0                                 BudgetBakers.com
# 1                             DApps Platform, Inc.
# 2                                      Airtm, Inc.
# 3                             MetaMask Web3 Wallet
# 4                                  Coinbase Wallet
# 5                     PT Espay Debit Indonesia Koe
# 6                  PT. Nusa Satu Inti Artha (DOKU)
# 7                                  WEMIX PTE. LTD.
# 8                               BitKeep Global Inc
# 9                                Hellenic Republic
# 10                           Wallet Cards Alliance
# 11                       PT Fintek Karya Nusantara
# 12                           Exodus Movement, Inc.
# 13                          TokenPocket Foundation
# 14                      Blockchain Luxembourg S.A.
# 15                                     Pera Wallet
# 16                          Wallet Passes Alliance
# 17                                         Coinomi
# 18                    IME Digital Solution Limited
# 19                                  SafePal Wallet
# 20                                    Soosu Studio
# 21                                           Cards
# 22                                    Jeton Wallet
# 23                            Solrise Research Ltd
# 24  Klever Wallet: Bitcoin, Ethereum, TRX & Crypto
# 25                    BlueWallet Services S. R. L.
# 26                                       DeFi Labs
# 27                                   MyEtherWallet
# 28                                     Bitcoin.com
# 29                                       Soramitsu
# 31                       PT Visionet Internasional
# 33           PT Fliptech Lentera Inspirasi Pertiwi
# 35                           Inti Dunia Sukses, PT
# 36                                         STICPAY
# 39             Dwijaya Mandiri Sejahtera Indonesia
# 40                                 ALFA TECHNOLOGY
# 41                               PayoApp Indonesia
# 42                       PT Visionet Internasional
# 43                       PT Bank Central Asia Tbk.
# 44         PT Bank Rakyat Indonesia (Persero) Tbk.
# 45                                           DIPAY
# 46                                    Ardhi Studio
# 47                                  Shine Co., LTD
# 48                                     BCA Digital
# 49                     Netzme Kreasi Indonesia, PT
# 50               Digital Banking Bank Neo Commerce
# 51                     PT. ALLO BANK INDONESIA Tbk
# 52                  PT Payfazz Teknologi Nusantara
# 53             PT Rpay Finansial Digital Indonesia
# 54                         Multi Digital Nusantara
# 55                 PT. Nusa Satu Inti Artha (DOKU)
# 56                      PT. BANK SEABANK INDONESIA
# 57                                     Reload Plus
#
#                                           description     installs  dev_status
# 0   <b>Wallet is a market-leading personal finance...   5,000,000+       False
# 1   Trust Wallet is the official crypto wallet of ...  10,000,000+       False
# 2   Access your money when you want, wherever you ...   1,000,000+       False
# 3   Whether you are an experienced user or brand n...  10,000,000+       False
# 4   Coinbase Wallet is your key to what’s next in ...   5,000,000+       False
# 5   DANA is Indonesia's digital wallet that can be...  50,000,000+        True
# 6   DOKU, layanan dompet digital yang membantu sip...   1,000,000+        True
# 7   <font color="#813ccc"><b>Integration with Vari...   1,000,000+       False
# 8   BitKeep is one of the top DeFi multi-chain cry...     100,000+       False
# 9   Το Gov.gr Wallet είναι η επίσημη ελληνική εφαρ...     500,000+       False
# 10  Across all wallet apps on Play Store, \r\nWall...   1,000,000+       False
# 11  LinkAja is a digital wallet from PT Fintek Kar...  10,000,000+        True
# 12  One wallet for cryptocurrency: Buy, exchange, ...   1,000,000+       False
# 13  TokenPocket is the leading multi-chain Crypto&...   1,000,000+       False
# 14  Blockchain.com is the world's most trusted pla...  10,000,000+       False
# 15  Pera Algo Wallet is the simple, fast way to se...     100,000+       False
# 16  With WalletPasses, you can use passes on your ...  10,000,000+       False
# 17  <b>The blockchain wallet trusted by millions.<...   1,000,000+       False
# 18  Experience the legacy of IME now on your smart...   1,000,000+       False
# 19  SafePal cryptocurrency wallet application - Yo...   1,000,000+       False
# 20  Manage all your cards in one app.\r\n\r\nFligh...     500,000+       False
# 21  <font color="#5a94f5"><b>Cards</b> is a mobile...   5,000,000+       False
# 22  Jeton Wallet gives you your own, personal digi...     100,000+       False
# 23  Solflare is a safe and powerful crypto wallet ...     100,000+       False
# 24  Klever app is a simple, powerful, smart, and s...   1,000,000+       False
# 25  A Bitcoin wallet that allows you to store, sen...     100,000+       False
# 26  Crypto.com DeFi Wallet is the best crypto wall...   1,000,000+       False
# 27  This is an official mobile app for MyEtherWall...     500,000+       False
# 28  Buy, sell, store, trade, and use cryptocurrenc...   5,000,000+       False
# 29  Fearless Wallet is designed for the decentrali...     100,000+       False
# 31  From snack times to mealtimes, from routine bi...  10,000,000+        True
# 33  <b>Transfer money to anywhere and anyone, dome...  10,000,000+        True
# 35  Rasakan pengalaman berbelanja dengan uang elek...   5,000,000+        True
# 36  Transfer and receive money faster and easier w...     100,000+       False
# 39  Aplikasi Transaksi Pulsa All in One\r\n\r\nIsi...      10,000+        True
# 40  Untuk meningkatkan pelayanan dan lebih mendeka...         100+        True
# 41  Uncang adalah akronim dari Uang Canggih adalah...         100+        True
# 42  Satu Langkah Kecil, Jutaan Kesempatan untuk me...   1,000,000+        True
# 43  Sakuku is an electronic money service for paym...   1,000,000+        True
# 44  BRImo merupakan Aplikasi Internet dan Mobile B...  10,000,000+        True
# 45  Dompet bukan sekadar dompet. Ini dompet yang a...       5,000+       False
# 46  OVO merupakan aplikasi smart yang memberikan A...         500+       False
# 47  If you are wondering whether you have money or...     100,000+       False
# 48  Mulai Langkahmu bareng blu!\r\nUntuk hidup leb...   1,000,000+        True
# 49  Pay anything, expand your network, leveling up...   1,000,000+        True
# 50  Saatnya nikmati berbagai kemudahan #BuatSemua ...  10,000,000+        True
# 51  Hi, kini Allo Bank versi Beta untuk Android ha...   1,000,000+        True
# 52  PAYFAZZ Agen, aplikasi PPOB super lengkap untu...   5,000,000+        True
# 53  Need to send money to Indonesia? Send money an...     100,000+        True
# 54  Saatnya berpindah ke dompet digital, satu domp...       1,000+       False
# 55  MPM WALLET, layanan dompet digital yang memban...      10,000+        True
# 56  Lebih Untung di SeaBank!\r\n \r\nBuka rekening...   5,000,000+        True
# 57  Dompet Mandiri adalah aplikasi bisnis untuk pe...         100+       False

# %% [markdown]
# ### Checking if the app is listed on the legal_bi dataset
#
# After we check whether the developer is already listed or not, next we need to further investigate if the app itself is already listed in Bank Indonesia.
#
# * We need to determine which method of Fuzzy String Matching best suited for the app name/title in our dataset.
#
# * Based on the previous finding, we narrow it down to two method which are `token_sort_ratio` and `token_set_ratio`
#
# We will try using `token_set_ratio` method first.

# %%
fuzz.token_sort_ratio('LinkAja / LinkAja Syariah', 'LinkAja')
# Out:
# 47

# %%
fuzz.token_sort_ratio('Jeton Wallet', 'One Wallet')
# Out:
# 82

# %% [markdown]
# It turns out it returns bad ratio score for same app with different naming in playstore, far below our initial minimum score.
#
# Next is using `token_set_ratio` again

# %%
fuzz.token_set_ratio('LinkAja / LinkAja Syariah', 'LinkAja')
# Out:
# 100

# %%
fuzz.token_set_ratio('Jeton Wallet', 'One Wallet')
# Out:
# 82

# %% [markdown]
# While it does finally return an excellent score for our LinkAja app name matching, it give a slighly higher score than our minimum ratio for a total different app.
#
# So for the app name matching, we will still be using `token_set_ratio` method but with higher minimum ratio score.

# %%
unlisted_app = []
listed_app = []

check_listed(result_df['title'], 
             legal_bi['product'], 
             unlisted_app, 
             listed_app,
             ratio_score = 83
            )

# %%
# Sample of app that are NOT LISTED in the legal_bi['product'] from the crawled dataset
unlisted_app[:10]
# Out:
# ['Wallet: Budget Expense Tracker',
#  'Trust: Crypto & Bitcoin Wallet',
#  'Airtm',
#  'MetaMask - Blockchain Wallet',
#  'Coinbase Wallet: NFTs & Crypto',
#  'WEMIX Wallet',
#  'BitKeep: Crypto DeFi Wallet',
#  'Gov.gr Wallet',
#  'Wallet Cards | Digital Wallet',
#  'Exodus: Crypto Bitcoin Wallet']

# %%
# Sample of app that are listed in the legal_bi['product'] from the crawled dataset
listed_app[:10]
# Out:
# ['DANA Indonesia Digital Wallet',
#  'DOKU',
#  'LinkAja / LinkAja Syariah',
#  'ONE Wallet - Empty your wallet',
#  'OVO',
#  'Flip: Transfer Without Admin',
#  'i.saku',
#  'OVO Merchant',
#  'Sakuku',
#  'Dipay']

# %%
# Create new column named 'app_status' where developer listed in listed_bi['product'] set as True
result_df['app_status'] = result_df['title'].isin(listed_app)

# %%
# Current state of our result_df dataframe where if app_status = false means the developer for each of the app is not 
# a listed product/app in the legal_bi dataset
result_df
# Out:
#                              title  \
# 0   Wallet: Budget Expense Tracker
# 1   Trust: Crypto & Bitcoin Wallet
# 2                            Airtm
# 3     MetaMask - Blockchain Wallet
# 4   Coinbase Wallet: NFTs & Crypto
# 5    DANA Indonesia Digital Wallet
# 6                             DOKU
# 7                     WEMIX Wallet
# 8      BitKeep: Crypto DeFi Wallet
# 9                    Gov.gr Wallet
# 10   Wallet Cards | Digital Wallet
# 11       LinkAja / LinkAja Syariah
# 12   Exodus: Crypto Bitcoin Wallet
# 13  TokenPocket Wallet Crypto DeFi
# 14  Blockchain.com Wallet: Buy BTC
# 15                Pera Algo Wallet
# 16  WalletPasses | Passbook Wallet
# 17  Coinomi: Crypto Bitcoin Wallet
# 18  IME Pay- Mobile Digital Wallet
# 19  SafePal-Crypto wallet BTC NFTs
# 20  ONE Wallet - Empty your wallet
# 21           Cards - Mobile Wallet
# 22                    Jeton Wallet
# 23        Solflare - Solana Wallet
# 24    Klever: Secure Crypto Wallet
# 25       BlueWallet Bitcoin Wallet
# 26        Crypto.com l DeFi Wallet
# 27    MEW wallet – Ethereum wallet
# 28  Bitcoin Wallet: BTC, ETH & BCH
# 29  Fearless Wallet: Polkadot, クサマ
# 31                             OVO
# 33    Flip: Transfer Without Admin
# 35                          i.saku
# 36                         STICPAY
# 39                  Dompet Digital
# 40              DAS Dompet Digital
# 41         Uncang - Dompet Digital
# 42                    OVO Merchant
# 43                          Sakuku
# 44                       BRImo BRI
# 45                           Dipay
# 46        Cek Saldo Dompet Digital
# 47                        E-Wallet
# 48              blu by BCA Digital
# 49                          NETZME
# 50       neobank: BNC digital bank
# 51                       Allo Bank
# 52  PAYFAZZ Agen: Pulsa & Transfer
# 53                       yourpayID
# 54                  Dompet Manfaat
# 55                      MPM Wallet
# 56                         SeaBank
# 57                  Dompet Mandiri
#
#                                          developer  \
# 0                                 BudgetBakers.com
# 1                             DApps Platform, Inc.
# 2                                      Airtm, Inc.
# 3                             MetaMask Web3 Wallet
# 4                                  Coinbase Wallet
# 5                     PT Espay Debit Indonesia Koe
# 6                  PT. Nusa Satu Inti Artha (DOKU)
# 7                                  WEMIX PTE. LTD.
# 8                               BitKeep Global Inc
# 9                                Hellenic Republic
# 10                           Wallet Cards Alliance
# 11                       PT Fintek Karya Nusantara
# 12                           Exodus Movement, Inc.
# 13                          TokenPocket Foundation
# 14                      Blockchain Luxembourg S.A.
# 15                                     Pera Wallet
# 16                          Wallet Passes Alliance
# 17                                         Coinomi
# 18                    IME Digital Solution Limited
# 19                                  SafePal Wallet
# 20                                    Soosu Studio
# 21                                           Cards
# 22                                    Jeton Wallet
# 23                            Solrise Research Ltd
# 24  Klever Wallet: Bitcoin, Ethereum, TRX & Crypto
# 25                    BlueWallet Services S. R. L.
# 26                                       DeFi Labs
# 27                                   MyEtherWallet
# 28                                     Bitcoin.com
# 29                                       Soramitsu
# 31                       PT Visionet Internasional
# 33           PT Fliptech Lentera Inspirasi Pertiwi
# 35                           Inti Dunia Sukses, PT
# 36                                         STICPAY
# 39             Dwijaya Mandiri Sejahtera Indonesia
# 40                                 ALFA TECHNOLOGY
# 41                               PayoApp Indonesia
# 42                       PT Visionet Internasional
# 43                       PT Bank Central Asia Tbk.
# 44         PT Bank Rakyat Indonesia (Persero) Tbk.
# 45                                           DIPAY
# 46                                    Ardhi Studio
# 47                                  Shine Co., LTD
# 48                                     BCA Digital
# 49                     Netzme Kreasi Indonesia, PT
# 50               Digital Banking Bank Neo Commerce
# 51                     PT. ALLO BANK INDONESIA Tbk
# 52                  PT Payfazz Teknologi Nusantara
# 53             PT Rpay Finansial Digital Indonesia
# 54                         Multi Digital Nusantara
# 55                 PT. Nusa Satu Inti Artha (DOKU)
# 56                      PT. BANK SEABANK INDONESIA
# 57                                     Reload Plus
#
#                                           description     installs  \
# 0   <b>Wallet is a market-leading personal finance...   5,000,000+
# 1   Trust Wallet is the official crypto wallet of ...  10,000,000+
# 2   Access your money when you want, wherever you ...   1,000,000+
# 3   Whether you are an experienced user or brand n...  10,000,000+
# 4   Coinbase Wallet is your key to what’s next in ...   5,000,000+
# 5   DANA is Indonesia's digital wallet that can be...  50,000,000+
# 6   DOKU, layanan dompet digital yang membantu sip...   1,000,000+
# 7   <font color="#813ccc"><b>Integration with Vari...   1,000,000+
# 8   BitKeep is one of the top DeFi multi-chain cry...     100,000+
# 9   Το Gov.gr Wallet είναι η επίσημη ελληνική εφαρ...     500,000+
# 10  Across all wallet apps on Play Store, \r\nWall...   1,000,000+
# 11  LinkAja is a digital wallet from PT Fintek Kar...  10,000,000+
# 12  One wallet for cryptocurrency: Buy, exchange, ...   1,000,000+
# 13  TokenPocket is the leading multi-chain Crypto&...   1,000,000+
# 14  Blockchain.com is the world's most trusted pla...  10,000,000+
# 15  Pera Algo Wallet is the simple, fast way to se...     100,000+
# 16  With WalletPasses, you can use passes on your ...  10,000,000+
# 17  <b>The blockchain wallet trusted by millions.<...   1,000,000+
# 18  Experience the legacy of IME now on your smart...   1,000,000+
# 19  SafePal cryptocurrency wallet application - Yo...   1,000,000+
# 20  Manage all your cards in one app.\r\n\r\nFligh...     500,000+
# 21  <font color="#5a94f5"><b>Cards</b> is a mobile...   5,000,000+
# 22  Jeton Wallet gives you your own, personal digi...     100,000+
# 23  Solflare is a safe and powerful crypto wallet ...     100,000+
# 24  Klever app is a simple, powerful, smart, and s...   1,000,000+
# 25  A Bitcoin wallet that allows you to store, sen...     100,000+
# 26  Crypto.com DeFi Wallet is the best crypto wall...   1,000,000+
# 27  This is an official mobile app for MyEtherWall...     500,000+
# 28  Buy, sell, store, trade, and use cryptocurrenc...   5,000,000+
# 29  Fearless Wallet is designed for the decentrali...     100,000+
# 31  From snack times to mealtimes, from routine bi...  10,000,000+
# 33  <b>Transfer money to anywhere and anyone, dome...  10,000,000+
# 35  Rasakan pengalaman berbelanja dengan uang elek...   5,000,000+
# 36  Transfer and receive money faster and easier w...     100,000+
# 39  Aplikasi Transaksi Pulsa All in One\r\n\r\nIsi...      10,000+
# 40  Untuk meningkatkan pelayanan dan lebih mendeka...         100+
# 41  Uncang adalah akronim dari Uang Canggih adalah...         100+
# 42  Satu Langkah Kecil, Jutaan Kesempatan untuk me...   1,000,000+
# 43  Sakuku is an electronic money service for paym...   1,000,000+
# 44  BRImo merupakan Aplikasi Internet dan Mobile B...  10,000,000+
# 45  Dompet bukan sekadar dompet. Ini dompet yang a...       5,000+
# 46  OVO merupakan aplikasi smart yang memberikan A...         500+
# 47  If you are wondering whether you have money or...     100,000+
# 48  Mulai Langkahmu bareng blu!\r\nUntuk hidup leb...   1,000,000+
# 49  Pay anything, expand your network, leveling up...   1,000,000+
# 50  Saatnya nikmati berbagai kemudahan #BuatSemua ...  10,000,000+
# 51  Hi, kini Allo Bank versi Beta untuk Android ha...   1,000,000+
# 52  PAYFAZZ Agen, aplikasi PPOB super lengkap untu...   5,000,000+
# 53  Need to send money to Indonesia? Send money an...     100,000+
# 54  Saatnya berpindah ke dompet digital, satu domp...       1,000+
# 55  MPM WALLET, layanan dompet digital yang memban...      10,000+
# 56  Lebih Untung di SeaBank!\r\n \r\nBuka rekening...   5,000,000+
# 57  Dompet Mandiri adalah aplikasi bisnis untuk pe...         100+
#
#     dev_status  app_status
# 0        False       False
# 1        False       False
# 2        False       False
# 3        False       False
# 4        False       False
# 5         True        True
# 6         True        True
# 7        False       False
# 8        False       False
# 9        False       False
# 10       False       False
# 11        True        True
# 12       False       False
# 13       False       False
# 14       False       False
# 15       False       False
# 16       False       False
# 17       False       False
# 18       False       False
# 19       False       False
# 20       False        True
# 21       False       False
# 22       False       False
# 23       False       False
# 24       False       False
# 25       False       False
# 26       False       False
# 27       False       False
# 28       False       False
# 29       False       False
# 31        True        True
# 33        True        True
# 35        True        True
# 36       False       False
# 39        True       False
# 40        True       False
# 41        True       False
# 42        True        True
# 43        True        True
# 44        True       False
# 45       False        True
# 46       False       False
# 47       False        True
# 48        True       False
# 49        True        True
# 50        True       False
# 51        True       False
# 52        True       False
# 53        True        True
# 54       False       False
# 55        True       False
# 56        True       False
# 57       False       False

# %% [markdown]
# ### Check Whether the App has Already Been Listed on Legal List of other Regulatory Organization
#
# As we know there are several regulatory organization in Indonesia, in our case we will also check if those app is already listed in other regulatory organization (OJK & Bappebti).

# %%
# Import List of Entities Listed in OJK
legal_ojk = pd.read_csv('legal_ojk.csv')
# Show sample of legal entities in OJK
legal_ojk.head()
# Out:
#                         organization  \
# 0            PT Ajaib Sekuritas Asia
# 1  PT Aldiracita Sekuritas Indonesia
# 2    PT Amantara Sekuritas Indonesia
# 3    PT Anugerah Sekuritas Indonesia
# 4       PT Artha Sekuritas Indonesia
#
#                                    prev_organization  \
# 0  PT Primasia Unggul Sekuritas PT Primasia Secur...
# 1                            PT Aldiracita Corpotama
# 2  PT Amantara Securities\nPT Kwik Tjandra Martoa...
# 3                        PT Anugerah Securindo Indah
# 4                      PT Artha Securities Indonesia
#
#                                              address
# 0  Neo Soho @ Podomoro City Lt. 30-03,  Jl. Letje...
# 1  Menara Tekno Lantai 9,  Jl. Fachrudin No. 19, ...
# 2  Sinar Mas Land Plaza Menara 3 Lantai 11, Jl. M...
# 3  Komp. Ruko Cempaka Mas  Blok M No. 1,2,3 Cempa...
# 4  Rukan Mangga Dua Square Blok F No.40, Jalan Gu...

# %%
listed_ojk = []
unlisted_ojk = []

check_listed(result_df['developer'], legal_ojk['organization'], unlisted_ojk, listed_ojk)

# %%
# Create new column named 'listed_ojk' where if an developer/organization listed in the legal_ojk list will be set as True
result_df['listed_ojk'] = result_df['developer'].isin(listed_ojk)
result_df.head()
# Out:
#                             title             developer  \
# 0  Wallet: Budget Expense Tracker      BudgetBakers.com
# 1  Trust: Crypto & Bitcoin Wallet  DApps Platform, Inc.
# 2                           Airtm           Airtm, Inc.
# 3    MetaMask - Blockchain Wallet  MetaMask Web3 Wallet
# 4  Coinbase Wallet: NFTs & Crypto       Coinbase Wallet
#
#                                          description     installs  dev_status  \
# 0  <b>Wallet is a market-leading personal finance...   5,000,000+       False
# 1  Trust Wallet is the official crypto wallet of ...  10,000,000+       False
# 2  Access your money when you want, wherever you ...   1,000,000+       False
# 3  Whether you are an experienced user or brand n...  10,000,000+       False
# 4  Coinbase Wallet is your key to what’s next in ...   5,000,000+       False
#
#    app_status  listed_ojk
# 0       False       False
# 1       False       False
# 2       False       False
# 3       False       False
# 4       False       False

# %%
# Import List of Entities Listed in Bappebti
legal_bappebti = pd.read_csv('legal_BAPPEBTI.csv')
# Show sample of legal entities in Bappebti
legal_bappebti.head()
# Out:
#                     organization                  reg_number      permit_date  \
# 0         PT TUMBUH BERSAMA NANO  007/BAPPEBTI/CP-AK/03/2022   3/22/2022 0:00
# 1  PT. KAGUM TEKNOLOGI INDONESIA  008/BAPPEBTI/CP-AK/04/2022   4/22/2022 0:00
# 2        PT. ASET DIGITAL BERKAT  001/BAPPEBTI/CP-AK/11/2019  11/21/2019 0:00
# 3     PT. ASET DIGITAL INDONESIA  005/BAPPEBTI/CP-AK/02/2022   2/11/2022 0:00
# 4     PT. BUMI SANTOSA CEMERLANG   012/BAPPEBTI/CP-AK/4/2022   4/28/2022 0:00
#
#                                        web  \
# 0                              nanovest.io
# 1        www.ptkagumteknologiindonesia.com
# 2                       www.tokocrypto.com
# 3                       www.incrypto.co.id
# 4  https://pluang.com/produk/pluang-crypto
#
#                                              address
# 0  Sinarmas MSIG Tower Lt. 37, Jl. Jend Sudirman ...
# 1  Neo Soho @Podomoro City, Jalan Letnan Jenderal...
# 2  AXA TOWER, JL. PROFESOR DOKTOR SATRIO, KAV. 18...
# 3  AXA Tower Lantai 36 Suite 02, Jalan Prof. Dr. ...
# 4  Ruko Inkopal KTC Blok F No. 42, Jl. Boulevard ...

# %%
listed_bappebti = []
unlisted_bappebti = []

check_listed(result_df['developer'], legal_bappebti['organization'], unlisted_bappebti, listed_bappebti)

# %%
# Create new column named 'listed_bappebti' where if an developer/organization listed in the legal_bappebti list will be set as True
result_df['listed_bappebti'] = result_df['developer'].isin(listed_bappebti)

# %%
result_df
# Out:
#                              title  \
# 0   Wallet: Budget Expense Tracker
# 1   Trust: Crypto & Bitcoin Wallet
# 2                            Airtm
# 3     MetaMask - Blockchain Wallet
# 4   Coinbase Wallet: NFTs & Crypto
# 5    DANA Indonesia Digital Wallet
# 6                             DOKU
# 7                     WEMIX Wallet
# 8      BitKeep: Crypto DeFi Wallet
# 9                    Gov.gr Wallet
# 10   Wallet Cards | Digital Wallet
# 11       LinkAja / LinkAja Syariah
# 12   Exodus: Crypto Bitcoin Wallet
# 13  TokenPocket Wallet Crypto DeFi
# 14  Blockchain.com Wallet: Buy BTC
# 15                Pera Algo Wallet
# 16  WalletPasses | Passbook Wallet
# 17  Coinomi: Crypto Bitcoin Wallet
# 18  IME Pay- Mobile Digital Wallet
# 19  SafePal-Crypto wallet BTC NFTs
# 20  ONE Wallet - Empty your wallet
# 21           Cards - Mobile Wallet
# 22                    Jeton Wallet
# 23        Solflare - Solana Wallet
# 24    Klever: Secure Crypto Wallet
# 25       BlueWallet Bitcoin Wallet
# 26        Crypto.com l DeFi Wallet
# 27    MEW wallet – Ethereum wallet
# 28  Bitcoin Wallet: BTC, ETH & BCH
# 29  Fearless Wallet: Polkadot, クサマ
# 31                             OVO
# 33    Flip: Transfer Without Admin
# 35                          i.saku
# 36                         STICPAY
# 39                  Dompet Digital
# 40              DAS Dompet Digital
# 41         Uncang - Dompet Digital
# 42                    OVO Merchant
# 43                          Sakuku
# 44                       BRImo BRI
# 45                           Dipay
# 46        Cek Saldo Dompet Digital
# 47                        E-Wallet
# 48              blu by BCA Digital
# 49                          NETZME
# 50       neobank: BNC digital bank
# 51                       Allo Bank
# 52  PAYFAZZ Agen: Pulsa & Transfer
# 53                       yourpayID
# 54                  Dompet Manfaat
# 55                      MPM Wallet
# 56                         SeaBank
# 57                  Dompet Mandiri
#
#                                          developer  \
# 0                                 BudgetBakers.com
# 1                             DApps Platform, Inc.
# 2                                      Airtm, Inc.
# 3                             MetaMask Web3 Wallet
# 4                                  Coinbase Wallet
# 5                     PT Espay Debit Indonesia Koe
# 6                  PT. Nusa Satu Inti Artha (DOKU)
# 7                                  WEMIX PTE. LTD.
# 8                               BitKeep Global Inc
# 9                                Hellenic Republic
# 10                           Wallet Cards Alliance
# 11                       PT Fintek Karya Nusantara
# 12                           Exodus Movement, Inc.
# 13                          TokenPocket Foundation
# 14                      Blockchain Luxembourg S.A.
# 15                                     Pera Wallet
# 16                          Wallet Passes Alliance
# 17                                         Coinomi
# 18                    IME Digital Solution Limited
# 19                                  SafePal Wallet
# 20                                    Soosu Studio
# 21                                           Cards
# 22                                    Jeton Wallet
# 23                            Solrise Research Ltd
# 24  Klever Wallet: Bitcoin, Ethereum, TRX & Crypto
# 25                    BlueWallet Services S. R. L.
# 26                                       DeFi Labs
# 27                                   MyEtherWallet
# 28                                     Bitcoin.com
# 29                                       Soramitsu
# 31                       PT Visionet Internasional
# 33           PT Fliptech Lentera Inspirasi Pertiwi
# 35                           Inti Dunia Sukses, PT
# 36                                         STICPAY
# 39             Dwijaya Mandiri Sejahtera Indonesia
# 40                                 ALFA TECHNOLOGY
# 41                               PayoApp Indonesia
# 42                       PT Visionet Internasional
# 43                       PT Bank Central Asia Tbk.
# 44         PT Bank Rakyat Indonesia (Persero) Tbk.
# 45                                           DIPAY
# 46                                    Ardhi Studio
# 47                                  Shine Co., LTD
# 48                                     BCA Digital
# 49                     Netzme Kreasi Indonesia, PT
# 50               Digital Banking Bank Neo Commerce
# 51                     PT. ALLO BANK INDONESIA Tbk
# 52                  PT Payfazz Teknologi Nusantara
# 53             PT Rpay Finansial Digital Indonesia
# 54                         Multi Digital Nusantara
# 55                 PT. Nusa Satu Inti Artha (DOKU)
# 56                      PT. BANK SEABANK INDONESIA
# 57                                     Reload Plus
#
#                                           description     installs  \
# 0   <b>Wallet is a market-leading personal finance...   5,000,000+
# 1   Trust Wallet is the official crypto wallet of ...  10,000,000+
# 2   Access your money when you want, wherever you ...   1,000,000+
# 3   Whether you are an experienced user or brand n...  10,000,000+
# 4   Coinbase Wallet is your key to what’s next in ...   5,000,000+
# 5   DANA is Indonesia's digital wallet that can be...  50,000,000+
# 6   DOKU, layanan dompet digital yang membantu sip...   1,000,000+
# 7   <font color="#813ccc"><b>Integration with Vari...   1,000,000+
# 8   BitKeep is one of the top DeFi multi-chain cry...     100,000+
# 9   Το Gov.gr Wallet είναι η επίσημη ελληνική εφαρ...     500,000+
# 10  Across all wallet apps on Play Store, \r\nWall...   1,000,000+
# 11  LinkAja is a digital wallet from PT Fintek Kar...  10,000,000+
# 12  One wallet for cryptocurrency: Buy, exchange, ...   1,000,000+
# 13  TokenPocket is the leading multi-chain Crypto&...   1,000,000+
# 14  Blockchain.com is the world's most trusted pla...  10,000,000+
# 15  Pera Algo Wallet is the simple, fast way to se...     100,000+
# 16  With WalletPasses, you can use passes on your ...  10,000,000+
# 17  <b>The blockchain wallet trusted by millions.<...   1,000,000+
# 18  Experience the legacy of IME now on your smart...   1,000,000+
# 19  SafePal cryptocurrency wallet application - Yo...   1,000,000+
# 20  Manage all your cards in one app.\r\n\r\nFligh...     500,000+
# 21  <font color="#5a94f5"><b>Cards</b> is a mobile...   5,000,000+
# 22  Jeton Wallet gives you your own, personal digi...     100,000+
# 23  Solflare is a safe and powerful crypto wallet ...     100,000+
# 24  Klever app is a simple, powerful, smart, and s...   1,000,000+
# 25  A Bitcoin wallet that allows you to store, sen...     100,000+
# 26  Crypto.com DeFi Wallet is the best crypto wall...   1,000,000+
# 27  This is an official mobile app for MyEtherWall...     500,000+
# 28  Buy, sell, store, trade, and use cryptocurrenc...   5,000,000+
# 29  Fearless Wallet is designed for the decentrali...     100,000+
# 31  From snack times to mealtimes, from routine bi...  10,000,000+
# 33  <b>Transfer money to anywhere and anyone, dome...  10,000,000+
# 35  Rasakan pengalaman berbelanja dengan uang elek...   5,000,000+
# 36  Transfer and receive money faster and easier w...     100,000+
# 39  Aplikasi Transaksi Pulsa All in One\r\n\r\nIsi...      10,000+
# 40  Untuk meningkatkan pelayanan dan lebih mendeka...         100+
# 41  Uncang adalah akronim dari Uang Canggih adalah...         100+
# 42  Satu Langkah Kecil, Jutaan Kesempatan untuk me...   1,000,000+
# 43  Sakuku is an electronic money service for paym...   1,000,000+
# 44  BRImo merupakan Aplikasi Internet dan Mobile B...  10,000,000+
# 45  Dompet bukan sekadar dompet. Ini dompet yang a...       5,000+
# 46  OVO merupakan aplikasi smart yang memberikan A...         500+
# 47  If you are wondering whether you have money or...     100,000+
# 48  Mulai Langkahmu bareng blu!\r\nUntuk hidup leb...   1,000,000+
# 49  Pay anything, expand your network, leveling up...   1,000,000+
# 50  Saatnya nikmati berbagai kemudahan #BuatSemua ...  10,000,000+
# 51  Hi, kini Allo Bank versi Beta untuk Android ha...   1,000,000+
# 52  PAYFAZZ Agen, aplikasi PPOB super lengkap untu...   5,000,000+
# 53  Need to send money to Indonesia? Send money an...     100,000+
# 54  Saatnya berpindah ke dompet digital, satu domp...       1,000+
# 55  MPM WALLET, layanan dompet digital yang memban...      10,000+
# 56  Lebih Untung di SeaBank!\r\n \r\nBuka rekening...   5,000,000+
# 57  Dompet Mandiri adalah aplikasi bisnis untuk pe...         100+
#
#     dev_status  app_status  listed_ojk  listed_bappebti
# 0        False       False       False            False
# 1        False       False       False            False
# 2        False       False       False            False
# 3        False       False       False            False
# 4        False       False       False            False
# 5         True        True       False            False
# 6         True        True       False            False
# 7        False       False       False            False
# 8        False       False       False            False
# 9        False       False       False            False
# 10       False       False       False            False
# 11        True        True       False            False
# 12       False       False       False            False
# 13       False       False       False            False
# 14       False       False       False            False
# 15       False       False       False            False
# 16       False       False       False            False
# 17       False       False       False            False
# 18       False       False       False            False
# 19       False       False       False            False
# 20       False        True       False            False
# 21       False       False       False            False
# 22       False       False       False            False
# 23       False       False       False            False
# 24       False       False       False            False
# 25       False       False       False            False
# 26       False       False       False            False
# 27       False       False       False            False
# 28       False       False       False            False
# 29       False       False       False            False
# 31        True        True       False             True
# 33        True        True       False            False
# 35        True        True       False            False
# 36       False       False       False            False
# 39        True       False       False            False
# 40        True       False       False            False
# 41        True       False       False            False
# 42        True        True       False             True
# 43        True        True       False            False
# 44        True       False       False            False
# 45       False        True       False            False
# 46       False       False       False            False
# 47       False        True       False            False
# 48        True       False        True             True
# 49        True        True       False            False
# 50        True       False       False            False
# 51        True       False        True            False
# 52        True       False       False            False
# 53        True        True       False             True
# 54       False       False       False            False
# 55        True       False       False            False
# 56        True       False        True            False
# 57       False       False       False            False

# %% [markdown]
# ### Look for Important Keyword from App Description Using Natural Language Processing (NLP) Keyword extraction
#
# Next we will try to extract important keywords from each app description, in hope we can later filter out unrelated keywords under payment system supervision.
#
# * We create a function called `get_keywords` that will extract important keywords, for this project we limit to max of 10 keywords to minimize the process.

# %%
def get_keywords(text, language='en', max_ngram_size=2, deduplication_threshold=0.5, deduplication_algo='seqm', windowSize=1, numOfKeywords = 10):
    kw_extractor = yake.KeywordExtractor(lan=language, 
                                         n=max_ngram_size, 
                                         dedupLim=deduplication_threshold,
                                         dedupFunc=deduplication_algo, 
                                         windowsSize=windowSize, 
                                         top=numOfKeywords, 
                                         features=None)
    keywords = kw_extractor.extract_keywords(text)
    sentences = []
    sentence_output = ""
    for word, number in keywords:
        sentence_output += word + " "
    sentences.append(sentence_output)
    sentences = sentences[0]
    return sentences

# %%
# The keywords will be stored in the list of keywords_list
keyword_list = []

for desc in result_df['description']:
    keyword_list.append(get_keywords(desc))

# %%
# Sample of keywords list being extracted
keyword_list[:5]
# Out:
# ['Wallet budget finances money spending save track bank synchronization personal finance accounts ',
#  'wallet support Trust Wallet Wallet support Trust Binance Wallet crypto Binance Bitcoin Ethereum ',
#  'money Access convert Receive local currency Airtm Receive payments wallets United States ',
#  'decentralized web MetaMask web digital assets experienced user digital assets blockchain internet wallet ',
#  'Coinbase Wallet Wallet crypto self-custody wallet Bitcoin Cash Ether Classic decentralized control Secure Element receive Bitcoin ']

# %% [markdown]
# Now we have an accurate list of keywords used from the app description of the application that we have crawled earlier.

# %% [markdown]
# ### Filter Unrelated Keywords That Most Likely Not Under Payment Systems
#
# From sample keywords above, we can see some of the apps are actually not related with e-wallet or electronic money (crypto, money spending tracker, etc) which under supervision of Bank Indonesia.
#
# So we will create a list of keywords that is not relatable with what we are trying to achieve.

# %%
unrelated_keywords = ['crypto wallet', 'Bitcoin', 'cryptocurrency', 'Ethereum', 
                      'crypto', 'Shiba Inu', 'Dogecoin', 'Solana', 'blockchain', 
                      'XRP', 'NFT', 'track spending', 'kripto' ]

# %% [markdown]
# ### Set Up Relevancy Score Based on the Extracted Keywords
#
# After we initiate the list of the potentially unrelated keywords instead of dropping all the app details those who posses any of those keywords, we will create a scoring system called relevancy score.
#
# * The lower the score means it has lower possibility to be out of scope from the payment system supervision.

# %%
def relevancy(payment_keywords, unrelated_keywords):
    total_score = 0
    for key in unrelated_keywords:
        result = fuzz.token_set_ratio(key,payment_keywords)
        total_score += result
    total_score /= len(unrelated_keywords)
    total_score = round(total_score,2)
    return total_score

# %%
relevancy_score = []

for keywords in keyword_list:
    relevancy_scr = relevancy(keywords, unrelated_keywords)
    relevancy_score.append(relevancy_scr)

# %% [markdown]
# We then add the relevancy_score to the result_df dataframe to see if each of the app is relevant with payment systems supervision.

# %%
result_df['relevancy_score'] = relevancy_score

# %% [markdown]
# We sort the list of app by the most relevant app based on scoring.

# %%
# Sort dataframe in ascending order based on relevancy score. Higher score means it's less relevant
result_df = result_df.sort_values('relevancy_score')

# %%
# Sample of our current final dataframe
result_df.head()
# Out:
#                              title                        developer  \
# 9                    Gov.gr Wallet                Hellenic Republic
# 6                             DOKU  PT. Nusa Satu Inti Artha (DOKU)
# 40              DAS Dompet Digital                  ALFA TECHNOLOGY
# 52  PAYFAZZ Agen: Pulsa & Transfer   PT Payfazz Teknologi Nusantara
# 56                         SeaBank       PT. BANK SEABANK INDONESIA
#
#                                           description    installs  dev_status  \
# 9   Το Gov.gr Wallet είναι η επίσημη ελληνική εφαρ...    500,000+       False
# 6   DOKU, layanan dompet digital yang membantu sip...  1,000,000+        True
# 40  Untuk meningkatkan pelayanan dan lebih mendeka...        100+        True
# 52  PAYFAZZ Agen, aplikasi PPOB super lengkap untu...  5,000,000+        True
# 56  Lebih Untung di SeaBank!\r\n \r\nBuka rekening...  5,000,000+        True
#
#     app_status  listed_ojk  listed_bappebti  relevancy_score
# 9        False       False            False             7.69
# 6         True       False            False            10.69
# 40       False       False            False            11.15
# 52       False       False            False            11.31
# 56       False        True            False            11.54

# %%
immediate_investigation = result_df[(result_df['dev_status']==False) & (result_df['app_status']==False)]

further_checking = result_df[((result_df['dev_status']==True) & (result_df['app_status']==False)) | 
                             ((result_df['dev_status']==False) & (result_df['app_status']==True)) ]

legally_listed = result_df[(result_df['dev_status']==True) & (result_df['app_status']==True)]

# %%
result_df
# Out:
#                              title  \
# 9                    Gov.gr Wallet
# 6                             DOKU
# 40              DAS Dompet Digital
# 52  PAYFAZZ Agen: Pulsa & Transfer
# 56                         SeaBank
# 35                          i.saku
# 46        Cek Saldo Dompet Digital
# 31                             OVO
# 11       LinkAja / LinkAja Syariah
# 39                  Dompet Digital
# 43                          Sakuku
# 57                  Dompet Mandiri
# 44                       BRImo BRI
# 42                    OVO Merchant
# 45                           Dipay
# 5    DANA Indonesia Digital Wallet
# 51                       Allo Bank
# 48              blu by BCA Digital
# 16  WalletPasses | Passbook Wallet
# 2                            Airtm
# 21           Cards - Mobile Wallet
# 41         Uncang - Dompet Digital
# 54                  Dompet Manfaat
# 20  ONE Wallet - Empty your wallet
# 33    Flip: Transfer Without Admin
# 49                          NETZME
# 36                         STICPAY
# 29  Fearless Wallet: Polkadot, クサマ
# 53                       yourpayID
# 50       neobank: BNC digital bank
# 55                      MPM Wallet
# 7                     WEMIX Wallet
# 22                    Jeton Wallet
# 10   Wallet Cards | Digital Wallet
# 47                        E-Wallet
# 18  IME Pay- Mobile Digital Wallet
# 8      BitKeep: Crypto DeFi Wallet
# 0   Wallet: Budget Expense Tracker
# 15                Pera Algo Wallet
# 3     MetaMask - Blockchain Wallet
# 25       BlueWallet Bitcoin Wallet
# 17  Coinomi: Crypto Bitcoin Wallet
# 26        Crypto.com l DeFi Wallet
# 23        Solflare - Solana Wallet
# 19  SafePal-Crypto wallet BTC NFTs
# 4   Coinbase Wallet: NFTs & Crypto
# 13  TokenPocket Wallet Crypto DeFi
# 28  Bitcoin Wallet: BTC, ETH & BCH
# 24    Klever: Secure Crypto Wallet
# 12   Exodus: Crypto Bitcoin Wallet
# 27    MEW wallet – Ethereum wallet
# 1   Trust: Crypto & Bitcoin Wallet
# 14  Blockchain.com Wallet: Buy BTC
#
#                                          developer  \
# 9                                Hellenic Republic
# 6                  PT. Nusa Satu Inti Artha (DOKU)
# 40                                 ALFA TECHNOLOGY
# 52                  PT Payfazz Teknologi Nusantara
# 56                      PT. BANK SEABANK INDONESIA
# 35                           Inti Dunia Sukses, PT
# 46                                    Ardhi Studio
# 31                       PT Visionet Internasional
# 11                       PT Fintek Karya Nusantara
# 39             Dwijaya Mandiri Sejahtera Indonesia
# 43                       PT Bank Central Asia Tbk.
# 57                                     Reload Plus
# 44         PT Bank Rakyat Indonesia (Persero) Tbk.
# 42                       PT Visionet Internasional
# 45                                           DIPAY
# 5                     PT Espay Debit Indonesia Koe
# 51                     PT. ALLO BANK INDONESIA Tbk
# 48                                     BCA Digital
# 16                          Wallet Passes Alliance
# 2                                      Airtm, Inc.
# 21                                           Cards
# 41                               PayoApp Indonesia
# 54                         Multi Digital Nusantara
# 20                                    Soosu Studio
# 33           PT Fliptech Lentera Inspirasi Pertiwi
# 49                     Netzme Kreasi Indonesia, PT
# 36                                         STICPAY
# 29                                       Soramitsu
# 53             PT Rpay Finansial Digital Indonesia
# 50               Digital Banking Bank Neo Commerce
# 55                 PT. Nusa Satu Inti Artha (DOKU)
# 7                                  WEMIX PTE. LTD.
# 22                                    Jeton Wallet
# 10                           Wallet Cards Alliance
# 47                                  Shine Co., LTD
# 18                    IME Digital Solution Limited
# 8                               BitKeep Global Inc
# 0                                 BudgetBakers.com
# 15                                     Pera Wallet
# 3                             MetaMask Web3 Wallet
# 25                    BlueWallet Services S. R. L.
# 17                                         Coinomi
# 26                                       DeFi Labs
# 23                            Solrise Research Ltd
# 19                                  SafePal Wallet
# 4                                  Coinbase Wallet
# 13                          TokenPocket Foundation
# 28                                     Bitcoin.com
# 24  Klever Wallet: Bitcoin, Ethereum, TRX & Crypto
# 12                           Exodus Movement, Inc.
# 27                                   MyEtherWallet
# 1                             DApps Platform, Inc.
# 14                      Blockchain Luxembourg S.A.
#
#                                           description     installs  \
# 9   Το Gov.gr Wallet είναι η επίσημη ελληνική εφαρ...     500,000+
# 6   DOKU, layanan dompet digital yang membantu sip...   1,000,000+
# 40  Untuk meningkatkan pelayanan dan lebih mendeka...         100+
# 52  PAYFAZZ Agen, aplikasi PPOB super lengkap untu...   5,000,000+
# 56  Lebih Untung di SeaBank!\r\n \r\nBuka rekening...   5,000,000+
# 35  Rasakan pengalaman berbelanja dengan uang elek...   5,000,000+
# 46  OVO merupakan aplikasi smart yang memberikan A...         500+
# 31  From snack times to mealtimes, from routine bi...  10,000,000+
# 11  LinkAja is a digital wallet from PT Fintek Kar...  10,000,000+
# 39  Aplikasi Transaksi Pulsa All in One\r\n\r\nIsi...      10,000+
# 43  Sakuku is an electronic money service for paym...   1,000,000+
# 57  Dompet Mandiri adalah aplikasi bisnis untuk pe...         100+
# 44  BRImo merupakan Aplikasi Internet dan Mobile B...  10,000,000+
# 42  Satu Langkah Kecil, Jutaan Kesempatan untuk me...   1,000,000+
# 45  Dompet bukan sekadar dompet. Ini dompet yang a...       5,000+
# 5   DANA is Indonesia's digital wallet that can be...  50,000,000+
# 51  Hi, kini Allo Bank versi Beta untuk Android ha...   1,000,000+
# 48  Mulai Langkahmu bareng blu!\r\nUntuk hidup leb...   1,000,000+
# 16  With WalletPasses, you can use passes on your ...  10,000,000+
# 2   Access your money when you want, wherever you ...   1,000,000+
# 21  <font color="#5a94f5"><b>Cards</b> is a mobile...   5,000,000+
# 41  Uncang adalah akronim dari Uang Canggih adalah...         100+
# 54  Saatnya berpindah ke dompet digital, satu domp...       1,000+
# 20  Manage all your cards in one app.\r\n\r\nFligh...     500,000+
# 33  <b>Transfer money to anywhere and anyone, dome...  10,000,000+
# 49  Pay anything, expand your network, leveling up...   1,000,000+
# 36  Transfer and receive money faster and easier w...     100,000+
# 29  Fearless Wallet is designed for the decentrali...     100,000+
# 53  Need to send money to Indonesia? Send money an...     100,000+
# 50  Saatnya nikmati berbagai kemudahan #BuatSemua ...  10,000,000+
# 55  MPM WALLET, layanan dompet digital yang memban...      10,000+
# 7   <font color="#813ccc"><b>Integration with Vari...   1,000,000+
# 22  Jeton Wallet gives you your own, personal digi...     100,000+
# 10  Across all wallet apps on Play Store, \r\nWall...   1,000,000+
# 47  If you are wondering whether you have money or...     100,000+
# 18  Experience the legacy of IME now on your smart...   1,000,000+
# 8   BitKeep is one of the top DeFi multi-chain cry...     100,000+
# 0   <b>Wallet is a market-leading personal finance...   5,000,000+
# 15  Pera Algo Wallet is the simple, fast way to se...     100,000+
# 3   Whether you are an experienced user or brand n...  10,000,000+
# 25  A Bitcoin wallet that allows you to store, sen...     100,000+
# 17  <b>The blockchain wallet trusted by millions.<...   1,000,000+
# 26  Crypto.com DeFi Wallet is the best crypto wall...   1,000,000+
# 23  Solflare is a safe and powerful crypto wallet ...     100,000+
# 19  SafePal cryptocurrency wallet application - Yo...   1,000,000+
# 4   Coinbase Wallet is your key to what’s next in ...   5,000,000+
# 13  TokenPocket is the leading multi-chain Crypto&...   1,000,000+
# 28  Buy, sell, store, trade, and use cryptocurrenc...   5,000,000+
# 24  Klever app is a simple, powerful, smart, and s...   1,000,000+
# 12  One wallet for cryptocurrency: Buy, exchange, ...   1,000,000+
# 27  This is an official mobile app for MyEtherWall...     500,000+
# 1   Trust Wallet is the official crypto wallet of ...  10,000,000+
# 14  Blockchain.com is the world's most trusted pla...  10,000,000+
#
#     dev_status  app_status  listed_ojk  listed_bappebti  relevancy_score
# 9        False       False       False            False             7.69
# 6         True        True       False            False            10.69
# 40        True       False       False            False            11.15
# 52        True       False       False            False            11.31
# 56        True       False        True            False            11.54
# 35        True        True       False            False            11.77
# 46       False       False       False            False            11.77
# 31        True        True       False             True            11.85
# 11        True        True       False            False            12.38
# 39        True       False       False            False            12.46
# 43        True        True       False            False            12.54
# 57       False       False       False            False            12.62
# 44        True       False       False            False            12.92
# 42        True        True       False             True            13.15
# 45       False        True       False            False            13.23
# 5         True        True       False            False            13.46
# 51        True       False        True            False            13.69
# 48        True       False        True             True            13.85
# 16       False       False       False            False            14.00
# 2        False       False       False            False            14.08
# 21       False       False       False            False            14.31
# 41        True       False       False            False            14.69
# 54       False       False       False            False            14.77
# 20       False        True       False            False            15.15
# 33        True        True       False            False            15.23
# 49        True        True       False            False            15.31
# 36       False       False       False            False            15.69
# 29       False       False       False            False            15.92
# 53        True        True       False             True            15.92
# 50        True       False       False            False            16.00
# 55        True       False       False            False            16.23
# 7        False       False       False            False            16.46
# 22       False       False       False            False            17.08
# 10       False       False       False            False            18.08
# 47       False        True       False            False            18.38
# 18       False       False       False            False            18.54
# 8        False       False       False            False            19.38
# 0        False       False       False            False            21.69
# 15       False       False       False            False            22.23
# 3        False       False       False            False            22.77
# 25       False       False       False            False            23.15
# 17       False       False       False            False            26.00
# 26       False       False       False            False            28.00
# 23       False       False       False            False            31.62
# 19       False       False       False            False            31.62
# 4        False       False       False            False            31.85
# 13       False       False       False            False            33.54
# 28       False       False       False            False            34.23
# 24       False       False       False            False            37.46
# 12       False       False       False            False            38.46
# 27       False       False       False            False            40.38
# 1        False       False       False            False            41.69
# 14       False       False       False            False            44.77

# %% [markdown]
# ### Final Outcome
#
# On the final step, we want to see the list of app that has potential to be furtherly investigated.
#
# Based on our method, we can categorize the list of app based on three different categories:
# * `Immediate Investigation` = if the developer and app are not listed (both set to False) in the legal_bi dataset.
# * `Further Checking` = if only one of the developer or the app is listed (only one is True) in the legal_bi dataset.
# * `Legally Listed` = if both the developer and the app are already listed in the legal_bi dataset.
#
# Do note we can also see whether the app is listed in other regulatory organization (OJK & Bappebti), if it turns out the developer or the app itself not legally listed in Bank Indonesia.

# %%
print('List of apps that needs immediate investigation are:' )
immediate_investigation
# Out:
# List of apps that needs immediate investigation are:
#                              title  \
# 9                    Gov.gr Wallet
# 46        Cek Saldo Dompet Digital
# 57                  Dompet Mandiri
# 16  WalletPasses | Passbook Wallet
# 2                            Airtm
# 21           Cards - Mobile Wallet
# 54                  Dompet Manfaat
# 36                         STICPAY
# 29  Fearless Wallet: Polkadot, クサマ
# 7                     WEMIX Wallet
# 22                    Jeton Wallet
# 10   Wallet Cards | Digital Wallet
# 18  IME Pay- Mobile Digital Wallet
# 8      BitKeep: Crypto DeFi Wallet
# 0   Wallet: Budget Expense Tracker
# 15                Pera Algo Wallet
# 3     MetaMask - Blockchain Wallet
# 25       BlueWallet Bitcoin Wallet
# 17  Coinomi: Crypto Bitcoin Wallet
# 26        Crypto.com l DeFi Wallet
# 23        Solflare - Solana Wallet
# 19  SafePal-Crypto wallet BTC NFTs
# 4   Coinbase Wallet: NFTs & Crypto
# 13  TokenPocket Wallet Crypto DeFi
# 28  Bitcoin Wallet: BTC, ETH & BCH
# 24    Klever: Secure Crypto Wallet
# 12   Exodus: Crypto Bitcoin Wallet
# 27    MEW wallet – Ethereum wallet
# 1   Trust: Crypto & Bitcoin Wallet
# 14  Blockchain.com Wallet: Buy BTC
#
#                                          developer  \
# 9                                Hellenic Republic
# 46                                    Ardhi Studio
# 57                                     Reload Plus
# 16                          Wallet Passes Alliance
# 2                                      Airtm, Inc.
# 21                                           Cards
# 54                         Multi Digital Nusantara
# 36                                         STICPAY
# 29                                       Soramitsu
# 7                                  WEMIX PTE. LTD.
# 22                                    Jeton Wallet
# 10                           Wallet Cards Alliance
# 18                    IME Digital Solution Limited
# 8                               BitKeep Global Inc
# 0                                 BudgetBakers.com
# 15                                     Pera Wallet
# 3                             MetaMask Web3 Wallet
# 25                    BlueWallet Services S. R. L.
# 17                                         Coinomi
# 26                                       DeFi Labs
# 23                            Solrise Research Ltd
# 19                                  SafePal Wallet
# 4                                  Coinbase Wallet
# 13                          TokenPocket Foundation
# 28                                     Bitcoin.com
# 24  Klever Wallet: Bitcoin, Ethereum, TRX & Crypto
# 12                           Exodus Movement, Inc.
# 27                                   MyEtherWallet
# 1                             DApps Platform, Inc.
# 14                      Blockchain Luxembourg S.A.
#
#                                           description     installs  \
# 9   Το Gov.gr Wallet είναι η επίσημη ελληνική εφαρ...     500,000+
# 46  OVO merupakan aplikasi smart yang memberikan A...         500+
# 57  Dompet Mandiri adalah aplikasi bisnis untuk pe...         100+
# 16  With WalletPasses, you can use passes on your ...  10,000,000+
# 2   Access your money when you want, wherever you ...   1,000,000+
# 21  <font color="#5a94f5"><b>Cards</b> is a mobile...   5,000,000+
# 54  Saatnya berpindah ke dompet digital, satu domp...       1,000+
# 36  Transfer and receive money faster and easier w...     100,000+
# 29  Fearless Wallet is designed for the decentrali...     100,000+
# 7   <font color="#813ccc"><b>Integration with Vari...   1,000,000+
# 22  Jeton Wallet gives you your own, personal digi...     100,000+
# 10  Across all wallet apps on Play Store, \r\nWall...   1,000,000+
# 18  Experience the legacy of IME now on your smart...   1,000,000+
# 8   BitKeep is one of the top DeFi multi-chain cry...     100,000+
# 0   <b>Wallet is a market-leading personal finance...   5,000,000+
# 15  Pera Algo Wallet is the simple, fast way to se...     100,000+
# 3   Whether you are an experienced user or brand n...  10,000,000+
# 25  A Bitcoin wallet that allows you to store, sen...     100,000+
# 17  <b>The blockchain wallet trusted by millions.<...   1,000,000+
# 26  Crypto.com DeFi Wallet is the best crypto wall...   1,000,000+
# 23  Solflare is a safe and powerful crypto wallet ...     100,000+
# 19  SafePal cryptocurrency wallet application - Yo...   1,000,000+
# 4   Coinbase Wallet is your key to what’s next in ...   5,000,000+
# 13  TokenPocket is the leading multi-chain Crypto&...   1,000,000+
# 28  Buy, sell, store, trade, and use cryptocurrenc...   5,000,000+
# 24  Klever app is a simple, powerful, smart, and s...   1,000,000+
# 12  One wallet for cryptocurrency: Buy, exchange, ...   1,000,000+
# 27  This is an official mobile app for MyEtherWall...     500,000+
# 1   Trust Wallet is the official crypto wallet of ...  10,000,000+
# 14  Blockchain.com is the world's most trusted pla...  10,000,000+
#
#     dev_status  app_status  listed_ojk  listed_bappebti  relevancy_score
# 9        False       False       False            False             7.69
# 46       False       False       False            False            11.77
# 57       False       False       False            False            12.62
# 16       False       False       False            False            14.00
# 2        False       False       False            False            14.08
# 21       False       False       False            False            14.31
# 54       False       False       False            False            14.77
# 36       False       False       False            False            15.69
# 29       False       False       False            False            15.92
# 7        False       False       False            False            16.46
# 22       False       False       False            False            17.08
# 10       False       False       False            False            18.08
# 18       False       False       False            False            18.54
# 8        False       False       False            False            19.38
# 0        False       False       False            False            21.69
# 15       False       False       False            False            22.23
# 3        False       False       False            False            22.77
# 25       False       False       False            False            23.15
# 17       False       False       False            False            26.00
# 26       False       False       False            False            28.00
# 23       False       False       False            False            31.62
# 19       False       False       False            False            31.62
# 4        False       False       False            False            31.85
# 13       False       False       False            False            33.54
# 28       False       False       False            False            34.23
# 24       False       False       False            False            37.46
# 12       False       False       False            False            38.46
# 27       False       False       False            False            40.38
# 1        False       False       False            False            41.69
# 14       False       False       False            False            44.77

# %%
print('List of apps that needs further checking are:' )
further_checking
# Out:
# List of apps that needs further checking are:
#                              title                                developer  \
# 40              DAS Dompet Digital                          ALFA TECHNOLOGY
# 52  PAYFAZZ Agen: Pulsa & Transfer           PT Payfazz Teknologi Nusantara
# 56                         SeaBank               PT. BANK SEABANK INDONESIA
# 39                  Dompet Digital      Dwijaya Mandiri Sejahtera Indonesia
# 44                       BRImo BRI  PT Bank Rakyat Indonesia (Persero) Tbk.
# 45                           Dipay                                    DIPAY
# 51                       Allo Bank              PT. ALLO BANK INDONESIA Tbk
# 48              blu by BCA Digital                              BCA Digital
# 41         Uncang - Dompet Digital                        PayoApp Indonesia
# 20  ONE Wallet - Empty your wallet                             Soosu Studio
# 50       neobank: BNC digital bank        Digital Banking Bank Neo Commerce
# 55                      MPM Wallet          PT. Nusa Satu Inti Artha (DOKU)
# 47                        E-Wallet                           Shine Co., LTD
#
#                                           description     installs  \
# 40  Untuk meningkatkan pelayanan dan lebih mendeka...         100+
# 52  PAYFAZZ Agen, aplikasi PPOB super lengkap untu...   5,000,000+
# 56  Lebih Untung di SeaBank!\r\n \r\nBuka rekening...   5,000,000+
# 39  Aplikasi Transaksi Pulsa All in One\r\n\r\nIsi...      10,000+
# 44  BRImo merupakan Aplikasi Internet dan Mobile B...  10,000,000+
# 45  Dompet bukan sekadar dompet. Ini dompet yang a...       5,000+
# 51  Hi, kini Allo Bank versi Beta untuk Android ha...   1,000,000+
# 48  Mulai Langkahmu bareng blu!\r\nUntuk hidup leb...   1,000,000+
# 41  Uncang adalah akronim dari Uang Canggih adalah...         100+
# 20  Manage all your cards in one app.\r\n\r\nFligh...     500,000+
# 50  Saatnya nikmati berbagai kemudahan #BuatSemua ...  10,000,000+
# 55  MPM WALLET, layanan dompet digital yang memban...      10,000+
# 47  If you are wondering whether you have money or...     100,000+
#
#     dev_status  app_status  listed_ojk  listed_bappebti  relevancy_score
# 40        True       False       False            False            11.15
# 52        True       False       False            False            11.31
# 56        True       False        True            False            11.54
# 39        True       False       False            False            12.46
# 44        True       False       False            False            12.92
# 45       False        True       False            False            13.23
# 51        True       False        True            False            13.69
# 48        True       False        True             True            13.85
# 41        True       False       False            False            14.69
# 20       False        True       False            False            15.15
# 50        True       False       False            False            16.00
# 55        True       False       False            False            16.23
# 47       False        True       False            False            18.38

# %%
print('List of apps that are legally listed are:' )
legally_listed
# Out:
# List of apps that are legally listed are:
#                             title                              developer  \
# 6                            DOKU        PT. Nusa Satu Inti Artha (DOKU)
# 35                         i.saku                  Inti Dunia Sukses, PT
# 31                            OVO              PT Visionet Internasional
# 11      LinkAja / LinkAja Syariah              PT Fintek Karya Nusantara
# 43                         Sakuku              PT Bank Central Asia Tbk.
# 42                   OVO Merchant              PT Visionet Internasional
# 5   DANA Indonesia Digital Wallet           PT Espay Debit Indonesia Koe
# 33   Flip: Transfer Without Admin  PT Fliptech Lentera Inspirasi Pertiwi
# 49                         NETZME            Netzme Kreasi Indonesia, PT
# 53                      yourpayID    PT Rpay Finansial Digital Indonesia
#
#                                           description     installs  \
# 6   DOKU, layanan dompet digital yang membantu sip...   1,000,000+
# 35  Rasakan pengalaman berbelanja dengan uang elek...   5,000,000+
# 31  From snack times to mealtimes, from routine bi...  10,000,000+
# 11  LinkAja is a digital wallet from PT Fintek Kar...  10,000,000+
# 43  Sakuku is an electronic money service for paym...   1,000,000+
# 42  Satu Langkah Kecil, Jutaan Kesempatan untuk me...   1,000,000+
# 5   DANA is Indonesia's digital wallet that can be...  50,000,000+
# 33  <b>Transfer money to anywhere and anyone, dome...  10,000,000+
# 49  Pay anything, expand your network, leveling up...   1,000,000+
# 53  Need to send money to Indonesia? Send money an...     100,000+
#
#     dev_status  app_status  listed_ojk  listed_bappebti  relevancy_score
# 6         True        True       False            False            10.69
# 35        True        True       False            False            11.77
# 31        True        True       False             True            11.85
# 11        True        True       False            False            12.38
# 43        True        True       False            False            12.54
# 42        True        True       False             True            13.15
# 5         True        True       False            False            13.46
# 33        True        True       False            False            15.23
# 49        True        True       False            False            15.31
# 53        True        True       False             True            15.92
