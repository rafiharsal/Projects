# %% [markdown]
# # Suptech Framework for Illegal Payment Service Provider App Detection in Indonesia Listed on Google PlayStore
#
# [By: Rafi Salman](https://www.linkedin.com/in/rafisalman/)

# %% [markdown]
# ### Scrape payment related app from Google Play Store using google_play_scraper
#
# First we need to obtain list of apps that are related with payment in google play store that available for download in Indonesia

# %%
from google_play_scraper import search
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import pandas as pd

# %%
# Below is only example of a keyword search ("wallet") to find payment related app specificaly in Indonesia
result = search('wallet',
                lang="id",  # Language in Indonesia (id)'
                country="id",  # Available for download in Indonesia (id)'
                n_hits=30 # limited to 30 (= Google's maximum)
)

# %%
# Store the dataset in form of dataframe
playstore = pd.DataFrame(result)
# Display the crawled result
playstore[:30]
# Out:
#                                appId  \
# 0   com.droid4you.application.wallet
# 1         com.wallet.crypto.trustapp
# 2                        io.metamask
# 3                  com.airtm.android
# 4                          org.toshi
# 5                 com.bitkeep.wallet
# 6         com.wemadetree.wemixwallet
# 7             com.dokuwallet.android
# 8               com.algorand.android
# 9             io.walletcards.android
# 10           piuk.blockchain.android
# 11             exodusmovement.exodus
# 12                 com.kucoin.wallet
# 13          jp.co.soramitsu.fearless
# 14            btc.org.freewallet.app
# 15              com.olacabs.olamoney
# 16                 vip.mytokenpocket
# 17                   com.defi.wallet
# 18           com.enjin.mobile.wallet
# 19             mw.org.freewallet.app
# 20                 io.safepal.wallet
# 21               com.bitcoin.mwallet
# 22                com.coinomi.wallet
# 23            eth.org.freewallet.app
# 24       com.kr.iotrust.dcent.wallet
# 25                io.oneinch.android
# 26                   io.atomicwallet
# 27                      im.token.app
# 28          io.bluewallet.bluewallet
# 29                  com.brise.wallet
#
#                                                  icon  \
# 0   https://play-lh.googleusercontent.com/DqAKT8mJ...
# 1   https://play-lh.googleusercontent.com/-3uTwEsZ...
# 2   https://play-lh.googleusercontent.com/8rzHJpfk...
# 3   https://play-lh.googleusercontent.com/sTc5uAZ8...
# 4   https://play-lh.googleusercontent.com/wrgUujbq...
# 5   https://play-lh.googleusercontent.com/9ejeZqAJ...
# 6   https://play-lh.googleusercontent.com/e4Vq3dIh...
# 7   https://play-lh.googleusercontent.com/yHAWkzRY...
# 8   https://play-lh.googleusercontent.com/InLGSL6V...
# 9   https://play-lh.googleusercontent.com/IKrNtdJI...
# 10  https://play-lh.googleusercontent.com/CcboHyK1...
# 11  https://play-lh.googleusercontent.com/d0y_tc6f...
# 12  https://play-lh.googleusercontent.com/ibPRCxWH...
# 13  https://play-lh.googleusercontent.com/cCe5KxgX...
# 14  https://play-lh.googleusercontent.com/CKjCKlDd...
# 15  https://play-lh.googleusercontent.com/duEfVHWa...
# 16  https://play-lh.googleusercontent.com/G_BiKQ5v...
# 17  https://play-lh.googleusercontent.com/8aXTeaP1...
# 18  https://play-lh.googleusercontent.com/UYqi4BNW...
# 19  https://play-lh.googleusercontent.com/pz4fXBrQ...
# 20  https://play-lh.googleusercontent.com/uT6ByyNv...
# 21  https://play-lh.googleusercontent.com/UnS9ktkc...
# 22  https://play-lh.googleusercontent.com/yFBkqYSx...
# 23  https://play-lh.googleusercontent.com/HII6PADU...
# 24  https://play-lh.googleusercontent.com/4GO-Bjl9...
# 25  https://play-lh.googleusercontent.com/1IWS86t5...
# 26  https://play-lh.googleusercontent.com/t8vnANR3...
# 27  https://play-lh.googleusercontent.com/URWnNCpB...
# 28  https://play-lh.googleusercontent.com/baXy546S...
# 29  https://play-lh.googleusercontent.com/N7M2QSue...
#
#                                           screenshots  \
# 0   [https://play-lh.googleusercontent.com/nC8X24D...
# 1   [https://play-lh.googleusercontent.com/HOAibhB...
# 2   [https://play-lh.googleusercontent.com/_bBbQOO...
# 3   [https://play-lh.googleusercontent.com/e1YARiO...
# 4   [https://play-lh.googleusercontent.com/DxQ03kq...
# 5   [https://play-lh.googleusercontent.com/m-c5wLt...
# 6   [https://play-lh.googleusercontent.com/UezCteC...
# 7   [https://play-lh.googleusercontent.com/qzAkuJP...
# 8   [https://play-lh.googleusercontent.com/UIMLGzf...
# 9   [https://play-lh.googleusercontent.com/FwPwGkA...
# 10  [https://play-lh.googleusercontent.com/71xHASj...
# 11  [https://play-lh.googleusercontent.com/8vdhSQy...
# 12  [https://play-lh.googleusercontent.com/PaTNX49...
# 13  [https://play-lh.googleusercontent.com/6OvP7Xh...
# 14  [https://play-lh.googleusercontent.com/B-PD2H9...
# 15  [https://play-lh.googleusercontent.com/Xi1BcKu...
# 16  [https://play-lh.googleusercontent.com/6nnq-rc...
# 17  [https://play-lh.googleusercontent.com/dCluA-3...
# 18  [https://play-lh.googleusercontent.com/RFDtxzA...
# 19  [https://play-lh.googleusercontent.com/5n0kWio...
# 20  [https://play-lh.googleusercontent.com/nSsqBCe...
# 21  [https://play-lh.googleusercontent.com/1OZLOAk...
# 22  [https://play-lh.googleusercontent.com/peVSX6i...
# 23  [https://play-lh.googleusercontent.com/IteqFqg...
# 24  [https://play-lh.googleusercontent.com/N89-ELR...
# 25  [https://play-lh.googleusercontent.com/GXmBjcx...
# 26  [https://play-lh.googleusercontent.com/jWmRcKv...
# 27  [https://play-lh.googleusercontent.com/kYj-3Op...
# 28  [https://play-lh.googleusercontent.com/kE5o0fM...
# 29  [https://play-lh.googleusercontent.com/dPNvGRy...
#
#                                           title     score               genre  \
# 0                     Wallet - Pelacak Anggaran  4.894325            Keuangan
# 1                         Trust - Dompet Kripto  4.710865            Keuangan
# 2                  MetaMask - Blockchain Wallet  4.471292            Keuangan
# 3                                         Airtm  3.800000            Keuangan
# 4                Coinbase Wallet: Simpan Kripto  3.235714            Keuangan
# 5                   BitKeep: Dompet Crypto DeFi  4.670520            Keuangan
# 6                                  WEMIX Wallet  3.932367            Keuangan
# 7                                          DOKU  3.270840            Keuangan
# 8                              Pera Algo Wallet  4.635514            Keuangan
# 9                 Wallet Cards | Digital Wallet  0.000000  Perjalanan & Lokal
# 10               Blockchain.com Wallet: Buy BTC  3.912467            Keuangan
# 11                Exodus: Crypto Bitcoin Wallet  4.820000            Keuangan
# 12                  KuCoin Wallet: Crypto & NFT  4.629310               Alat
# 13               Fearless Wallet: Polkadot, クサマ  4.571429            Keuangan
# 14               Dompet Bitcoin Aman Freewallet  4.186274            Keuangan
# 15                  Ola Money - Wallet payments  4.166666            Keuangan
# 16               TokenPocket Wallet Crypto DeFi  4.586364            Keuangan
# 17                     Crypto.com l DeFi Wallet  4.270000            Keuangan
# 18  Enjin: Bitcoin, Ethereum, Dompet Kripto NFT  4.440000            Keuangan
# 19                  BTC & Altcoin crypto wallet  3.940000            Keuangan
# 20               SafePal-Crypto wallet BTC NFTs  4.323442            Keuangan
# 21               Bitcoin Wallet: BTC, ETH & BCH  4.472000            Keuangan
# 22               Coinomi: Crypto Bitcoin Wallet  4.586035            Keuangan
# 23               Ethereum Wallet - ETH exchange  4.600000            Keuangan
# 24                         D'CENT Crypto Wallet  3.450000            Keuangan
# 25                    1inch: Wallet Crypto DeFi  4.571429            Keuangan
# 26               Bitcoin Wallet Crypto Ethereum  4.373626            Keuangan
# 27                imToken: Crypto & DeFi Wallet  3.544554            Keuangan
# 28                    BlueWallet Bitcoin Wallet  4.333334            Keuangan
# 29                        BRISE - Crypto Wallet  3.320000            Keuangan
#
#     price  free currency                                              video  \
# 0       0  True      IDR  https://www.youtube.com/embed/kAI9yu0U7Gw?ps=p...
# 1       0  True      IDR                                               None
# 2       0  True      IDR  https://www.youtube.com/embed/YVgfHZMFFFQ?ps=p...
# 3       0  True      IDR  https://www.youtube.com/embed/8u8WPL0acz0?ps=p...
# 4       0  True      IDR                                               None
# 5       0  True      IDR  https://www.youtube.com/embed/FskRmYjXqbY?ps=p...
# 6       0  True      IDR                                               None
# 7       0  True      IDR                                               None
# 8       0  True      IDR                                               None
# 9       0  True      IDR                                               None
# 10      0  True      IDR                                               None
# 11      0  True      IDR                                               None
# 12      0  True      IDR  https://www.youtube.com/embed/XdcAgTmEPuE?ps=p...
# 13      0  True      IDR  https://www.youtube.com/embed/2E0Kbo6B1Co?ps=p...
# 14      0  True      IDR  https://www.youtube.com/embed/H1kH8ZmDYjU?ps=p...
# 15      0  True      IDR  https://www.youtube.com/embed/8zZLtZSetv0?ps=p...
# 16      0  True      IDR                                               None
# 17      0  True      IDR  https://www.youtube.com/embed/7Q656yyxsHk?ps=p...
# 18      0  True      IDR                                               None
# 19      0  True      IDR  https://www.youtube.com/embed/Ze_a4NUKk2Q?ps=p...
# 20      0  True      IDR  https://www.youtube.com/embed/iCe1bRxpFPI?ps=p...
# 21      0  True      IDR  https://www.youtube.com/embed/WCM21CdKd58?ps=p...
# 22      0  True      IDR                                               None
# 23      0  True      IDR  https://www.youtube.com/embed/Ze_a4NUKk2Q?ps=p...
# 24      0  True      IDR                                               None
# 25      0  True      IDR                                               None
# 26      0  True      IDR                                               None
# 27      0  True      IDR  https://www.youtube.com/embed/0xUXWwt1lV0?ps=p...
# 28      0  True      IDR                                               None
# 29      0  True      IDR  https://www.youtube.com/embed/nK6E8QnQuBw?ps=p...
#
#                                           videoImage  \
# 0   https://i.ytimg.com/vi/kAI9yu0U7Gw/hqdefault.jpg
# 1                                               None
# 2   https://i.ytimg.com/vi/YVgfHZMFFFQ/hqdefault.jpg
# 3   https://i.ytimg.com/vi/8u8WPL0acz0/hqdefault.jpg
# 4                                               None
# 5   https://i.ytimg.com/vi/FskRmYjXqbY/hqdefault.jpg
# 6                                               None
# 7                                               None
# 8                                               None
# 9                                               None
# 10                                              None
# 11                                              None
# 12  https://i.ytimg.com/vi/XdcAgTmEPuE/hqdefault.jpg
# 13  https://i.ytimg.com/vi/2E0Kbo6B1Co/hqdefault.jpg
# 14  https://i.ytimg.com/vi/H1kH8ZmDYjU/hqdefault.jpg
# 15  https://i.ytimg.com/vi/8zZLtZSetv0/hqdefault.jpg
# 16                                              None
# 17  https://i.ytimg.com/vi/7Q656yyxsHk/hqdefault.jpg
# 18                                              None
# 19  https://i.ytimg.com/vi/Ze_a4NUKk2Q/hqdefault.jpg
# 20  https://i.ytimg.com/vi/iCe1bRxpFPI/hqdefault.jpg
# 21  https://i.ytimg.com/vi/WCM21CdKd58/hqdefault.jpg
# 22                                              None
# 23  https://i.ytimg.com/vi/Ze_a4NUKk2Q/hqdefault.jpg
# 24                                              None
# 25                                              None
# 26                                              None
# 27  https://i.ytimg.com/vi/0xUXWwt1lV0/hqdefault.jpg
# 28                                              None
# 29  https://i.ytimg.com/vi/nK6E8QnQuBw/hqdefault.jpg
#
#                                           description  \
# 0   <b>Wallet membantu Anda merencanakan anggaran ...
# 1   Trust Wallet adalah dompet kripto resmi Binanc...
# 2   Whether you are an experienced user or brand n...
# 3   Mueve y usa tu dinero como y cuando quieras, e...
# 4   Coinbase Wallet adalah kunci Anda menuju hal b...
# 5   Didirikan di Singapura pada Mei 2018, BitKeep ...
# 6   <font color="#813ccc"><b>Integration with Vari...
# 7   DOKU, layanan dompet digital yang membantu sip...
# 8   Pera Algo Wallet is the simple, fast way to se...
# 9   Across all wallet apps on Play Store, \r\nWall...
# 10  Blockchain.com is the world's most trusted pla...
# 11  Buy, exchange, stake, and earn interest on cry...
# 12  KuCoin Wallet is the official crypto wallet of...
# 13  Fearless Wallet is designed for the decentrali...
# 14  Instal dompet Bitcoin Aman dari Freewallet dan...
# 15  Introducing the all new OLA Money wallet App!\...
# 16  TokenPocket is the leading multi-chain Crypto&...
# 17  Crypto.com DeFi Wallet is the best crypto wall...
# 18  <b>Dibuat untuk perdagangan kripto</b>\r\n\r\n...
# 19  Install Cryptocurrency Wallet yang transaksi d...
# 20  SafePal cryptocurrency wallet application - Yo...
# 21  Buy, sell, store, trade, and use cryptocurrenc...
# 22  <b>The blockchain wallet trusted by millions.<...
# 23  Menyimpan, mengirim, dan menerima ETH mengguna...
# 24  D'CENT Wallet memungkinkan Anda untuk menyimpa...
# 25  Wallet 1inch adalah wallet crypto non-kustodia...
# 26  Atomic Wallet is universal non-custodial app f...
# 27  imToken is your secure crypto and bitcoin wall...
# 28  A Bitcoin wallet that allows you to store, sen...
# 29  BRISE Wallet is the official crypto wallet of ...
#
#                                       descriptionHTML  \
# 0   <b>Wallet membantu Anda merencanakan anggaran ...
# 1   Trust Wallet adalah dompet kripto resmi Binanc...
# 2   Whether you are an experienced user or brand n...
# 3   Mueve y usa tu dinero como y cuando quieras, e...
# 4   Coinbase Wallet adalah kunci Anda menuju hal b...
# 5   Didirikan di Singapura pada Mei 2018, BitKeep ...
# 6   <font color="#813ccc"><b>Integration with Vari...
# 7   DOKU, layanan dompet digital yang membantu sip...
# 8   Pera Algo Wallet is the simple, fast way to se...
# 9   Across all wallet apps on Play Store, <br>Wall...
# 10  Blockchain.com is the world&#39;s most trusted...
# 11  Buy, exchange, stake, and earn interest on cry...
# 12  KuCoin Wallet is the official crypto wallet of...
# 13  Fearless Wallet is designed for the decentrali...
# 14  Instal dompet Bitcoin Aman dari Freewallet dan...
# 15  Introducing the all new OLA Money wallet App!<...
# 16  TokenPocket is the leading multi-chain Crypto&...
# 17  Crypto.com DeFi Wallet is the best crypto wall...
# 18  <b>Dibuat untuk perdagangan kripto</b><br><br>...
# 19  Install Cryptocurrency Wallet yang transaksi d...
# 20  SafePal cryptocurrency wallet application - Yo...
# 21  Buy, sell, store, trade, and use cryptocurrenc...
# 22  <b>The blockchain wallet trusted by millions.<...
# 23  Menyimpan, mengirim, dan menerima ETH mengguna...
# 24  D&#39;CENT Wallet memungkinkan Anda untuk meny...
# 25  Wallet 1inch adalah wallet crypto non-kustodia...
# 26  Atomic Wallet is universal non-custodial app f...
# 27  imToken is your secure crypto and bitcoin wall...
# 28  A Bitcoin wallet that allows you to store, sen...
# 29  BRISE Wallet is the official crypto wallet of ...
#
#                           developer     installs
# 0                  BudgetBakers.com   5.000.000+
# 1              DApps Platform, Inc.  10.000.000+
# 2              MetaMask Web3 Wallet  10.000.000+
# 3                       Airtm, Inc.   1.000.000+
# 4                   Coinbase Wallet   5.000.000+
# 5                BitKeep Global Inc     100.000+
# 6                   WEMIX PTE. LTD.   1.000.000+
# 7   PT. Nusa Satu Inti Artha (DOKU)   1.000.000+
# 8                       Pera Wallet     100.000+
# 9             Wallet Cards Alliance   1.000.000+
# 10       Blockchain Luxembourg S.A.  10.000.000+
# 11            Exodus Movement, Inc.   1.000.000+
# 12                    KuCoin Wallet      10.000+
# 13                        Soramitsu     100.000+
# 14      Freewallet - Crypto Service   1.000.000+
# 15                              ola   1.000.000+
# 16           TokenPocket Foundation   1.000.000+
# 17                        DeFi Labs   1.000.000+
# 18                    Enjin PTE LTD   1.000.000+
# 19      Freewallet - Crypto Service     500.000+
# 20                   SafePal Wallet   1.000.000+
# 21                      Bitcoin.com   5.000.000+
# 22                          Coinomi   1.000.000+
# 23      Freewallet - Crypto Service   1.000.000+
# 24                 IoTrust Co., Ltd     100.000+
# 25                 1inch Foundation      10.000+
# 26                    Atomic Wallet   1.000.000+
# 27                 IMTOKEN PTE.LTD.     500.000+
# 28     BlueWallet Services S. R. L.     100.000+
# 29              CRYPTOEXCHANGER LTD      50.000+

# %% [markdown]
# ### Upload List of Legal Payment Service Provider Dataset
# Next, we upload the List of Legal Payment Service Provider as dataframe

# %%
legal_psp = pd.read_csv('legal_PSP.csv')
# Example of legal PSP on the dataset, the dataframe has gone through preprocessing before uploaded
legal_psp[:5]
# Out:
#                                        organization product  \
# 0        PT Pan Indonesia Bank, Tbk (PT Bank Panin)     NaN
# 1  Lembaga Pelatihan Kerja Alfamart Learning Center     NaN
# 2                           PT Citra Abdi Valasindo     NaN
# 3                         PT Dewata Inter Valasindo     NaN
# 4                          PT Luxury Valuta Perkasa     NaN
#
#                                              address telephone  \
# 0  Gedung Panin Centre Lt. 1-2, Jl. Jend. Sudirma...       NaN
# 1  Alfa Tower Lantai 19, Alamat Sutera, Jl. Jalur...       NaN
# 2  Wisma Bumiputera Lt. 2/M, Jl. Jendral Sudirman...       NaN
# 3  Jl. Bulungan I No. 64, Gedung Ayam Bulungan Lt...       NaN
# 4  Jalan Panglima Polim Raya No. 105, Kel. Melawa...       NaN
#
#                            category         decision_number decision_date  \
# 0                              QRIS       24/303/DKSP/Srt/B      8/8/2022
# 1            Job Training Institute  24/159/DPSP-GESK/Srt/B     7/27/2022
# 2  Non Bank Money Changer Operators  24/37/KEP.PBI/Jkt/2022      7/8/2022
# 3  Non Bank Money Changer Operators  24/39/KEP.PBI/Jkt/2022      7/8/2022
# 4  Non Bank Money Changer Operators  24/40/KEP.PBI/Jkt/2022      7/8/2022
#
#                              permit_place operational_date  \
# 0  Departemen Kebijakan Sistem Pembayaran              NaN
# 1                                 Jakarta              NaN
# 2              KPwBI Provinsi DKI Jakarta        7/11/2022
# 3              KPwBI Provinsi DKI Jakarta        7/18/2022
# 4              KPwBI Provinsi DKI Jakarta        7/12/2022
#
#                         description                         status  \
# 0                    QRIS Operators  Berizin (Belum Beroperasinal)
# 1            Job Training Institute    Berizin (Telah Operasional)
# 2  Non Bank Money Changer Operators    Berizin (Telah Operasional)
# 3  Non Bank Money Changer Operators    Berizin (Telah Operasional)
# 4  Non Bank Money Changer Operators    Berizin (Telah Operasional)
#
#            barcode email website
# 0              NaN   NaN     NaN
# 1              NaN   NaN     NaN
# 2  1424.48-000/Jkt   NaN     NaN
# 3  1423.47-000/Jkt   NaN     NaN
# 4  1422.46-001/Jkt   NaN     NaN

# %% [markdown]
# ### Using NLP Fuzzy String Matching between playstore["developer"] and legal_psp['organization']
#
# We will use Fuzzywuzzy library for this part. Fuzzywuzzy library is a Python library that uses Levenshtein Distance to calculate the differences between sequences in a simple-to-use package.
#
# Using this data set, we are going to test how Fuzzywuzzy thinks. In another words, we are using Fuzzywuzzy to match records between two data sources.
#
# Since the problem is that the publisher company or developer listed on playstore['developer'] might different than the one listed in the legal_psp['organization'] list
#
# There are several ways to compare two strings in Fuzzywuzzy, let’s try them one by one.

# %% [markdown]
# `ratio`, compares the entire string similarity, in order.

# %%
# fuzz.ratio(Playstore[title],list_berizin[nama_penyelenggara])
fuzz.ratio('PT. Sprint Asia Technology', 'PT Sprint Asia Technology')
# Out:
# 98

# %%
fuzz.ratio('PT. Nusa Satu Inti Artha (DOKU)', 'PT Nusa Satu Inti Artha')
# Out:
# 85

# %%
fuzz.ratio('PT.BANK PEMBANGUNAN DAERAH JAWA BARAT & BANTEN,TBK', 'PT Bank Jabar dan Banten')
# Out:
# 24

# %% [markdown]
# 'PT.BANK PEMBANGUNAN DAERAH JAWA BARAT & BANTEN,TBK' and 'PT Bank Jabar dan Banten' even though we know that both are the same entity is only 24% the same.  It turns out, the naive approach is far too sensitive to minor differences in word order, missing or extra words, and other such issues.

# %% [markdown]
# Next we use `partial_ratio`, as it compares partial string similarity using the same data pairs

# %%
# fuzz.partial_ratio(Playstore[title],list_berizin[nama_penyelenggara])
fuzz.partial_ratio('PT. Sprint Asia Technology', 'PT Sprint Asia Technology')
# Out:
# 96

# %%
fuzz.partial_ratio('PT. Nusa Satu Inti Artha (DOKU)', 'PT Nusa Satu Inti Artha')
# Out:
# 96

# %%
fuzz.partial_ratio('PT.BANK PEMBANGUNAN DAERAH JAWA BARAT & BANTEN,TBK', 'PT Bank Jabar dan Banten')
# Out:
# 21

# %% [markdown]
# For this data set, comparing partial string while it does bring better score for one result, but it's not the same case with the others.

# %% [markdown]
# The next method is `token_sort_ratio`, token_sort_ratio will ignores word order.

# %%
# fuzz.token_sort_ratio(Playstore[title],list_berizin[nama_penyelenggara])
fuzz.token_sort_ratio('PT. Sprint Asia Technology', 'PT Sprint Asia Technology')
# Out:
# 100

# %%
fuzz.token_sort_ratio('PT. Nusa Satu Inti Artha (DOKU)', 'PT Nusa Satu Inti Artha')
# Out:
# 90

# %%
fuzz.token_sort_ratio('PT.BANK PEMBANGUNAN DAERAH JAWA BARAT & BANTEN,TBK', 'PT Bank Jabar dan Banten')
# Out:
# 61

# %% [markdown]
# This method has the best result so far, we take look at the final method

# %% [markdown]
# `token_set_ratio`, it will ignores duplicated words. It is similar with token sort ratio, but a little bit more flexible.`

# %%
# fuzz.token_set_ratio(Playstore[title],list_berizin[nama_penyelenggara])
fuzz.token_set_ratio('PT. Sprint Asia Technology', 'PT Sprint Asia Technology')
# Out:
# 100

# %%
fuzz.token_set_ratio('PT. Nusa Satu Inti Artha (DOKU)', 'PT Nusa Satu Inti Artha')
# Out:
# 100

# %%
fuzz.token_set_ratio('PT.BANK PEMBANGUNAN DAERAH JAWA BARAT & BANTEN,TBK', 'PT Bank Jabar dan Banten')
# Out:
# 74

# %% [markdown]
# Looks like `token_set_ratio` is the best fit for our dataset. According to this discovery, we decided to apply token_set_ratio for the developer/organization matching.

# %%
dev_test = ['PT. Sprint Asia Technology', 'PT. Nusa Satu Inti Artha (DOKU)', 'PT.BANK PEMBANGUNAN DAERAH JAWA BARAT & BANTEN,TBK']
org_test = ['PT Sprint Asia Technology', 'PT Nusa Satu Inti Artha', 'PT Bank Jabar dan Banten']

for dev in dev_test:
    print(dev, process.extract(dev, org_test, scorer = fuzz.token_set_ratio, limit =1 ))
# Out:
# PT. Sprint Asia Technology [('PT Sprint Asia Technology', 100)]
# PT. Nusa Satu Inti Artha (DOKU) [('PT Nusa Satu Inti Artha', 100)]
# PT.BANK PEMBANGUNAN DAERAH JAWA BARAT & BANTEN,TBK [('PT Bank Jabar dan Banten', 74)]

# %% [markdown]
# ### Checking if the developer company is listed on the legal_PSP list

# %%
# Create new dataframe for the crawled playstore dataset to keep the original safe
result_df = playstore[['title', 'developer', 'description']].copy()

# %%
dev_test = ['PT. Sprint Asia Technology', 'PT. Nusa Satu Inti Artha (DOKU)', 'PT.BANK PEMBANGUNAN DAERAH JAWA BARAT & BANTEN,TBK']
org_test = ['PT Sprint Asia Technology', 'PT Nusa Satu Inti Artha', 'PT Bank Jabar dan Banten']

for dev in dev_test:
    print(dev, process.extract(dev, org_test, scorer = fuzz.token_set_ratio, limit =1 ))
# Out:
# PT. Sprint Asia Technology [('PT Sprint Asia Technology', 100)]
# PT. Nusa Satu Inti Artha (DOKU) [('PT Nusa Satu Inti Artha', 100)]
# PT.BANK PEMBANGUNAN DAERAH JAWA BARAT & BANTEN,TBK [('PT Bank Jabar dan Banten', 74)]

# %%
listed_developer = []
unlisted_developer = []

for dev in result_df['developer']:
    result = process.extractOne(dev, legal_psp['organization'], scorer = fuzz.token_set_ratio)
    ratio = int(result[1])
    if ratio < 70:
        unlisted_developer.append(dev)
    else:
        listed_developer.append(dev)

# %%
# Sample of developer that are listed in the legal_psp['organization'] from the crawled dataset
listed_developer[:5]
# Out:
# ['PT. Nusa Satu Inti Artha (DOKU)']

# %%
# Sample of developer that are NOT LISTED in the legal_psp['organization'] from the crawled dataset
unlisted_developer[:5]
# Out:
# ['BudgetBakers.com',
#  'DApps Platform, Inc.',
#  'MetaMask Web3 Wallet',
#  'Airtm, Inc.',
#  'Coinbase Wallet']

# %%
# Create new column named 'dev_status' where developer listed in listed_psp['organization'] set as True
result_df['dev_status'] = result_df['developer'].isin(listed_developer)

# %%
# Current state of our result_df dataframe where if dev_status == false means the developer for each of the app is not 
# a listed organization in the legal_psp dataset
result_df
# Out:
#                                           title  \
# 0                     Wallet - Pelacak Anggaran
# 1                         Trust - Dompet Kripto
# 2                  MetaMask - Blockchain Wallet
# 3                                         Airtm
# 4                Coinbase Wallet: Simpan Kripto
# 5                   BitKeep: Dompet Crypto DeFi
# 6                                  WEMIX Wallet
# 7                                          DOKU
# 8                              Pera Algo Wallet
# 9                 Wallet Cards | Digital Wallet
# 10               Blockchain.com Wallet: Buy BTC
# 11                Exodus: Crypto Bitcoin Wallet
# 12                  KuCoin Wallet: Crypto & NFT
# 13               Fearless Wallet: Polkadot, クサマ
# 14               Dompet Bitcoin Aman Freewallet
# 15                  Ola Money - Wallet payments
# 16               TokenPocket Wallet Crypto DeFi
# 17                     Crypto.com l DeFi Wallet
# 18  Enjin: Bitcoin, Ethereum, Dompet Kripto NFT
# 19                  BTC & Altcoin crypto wallet
# 20               SafePal-Crypto wallet BTC NFTs
# 21               Bitcoin Wallet: BTC, ETH & BCH
# 22               Coinomi: Crypto Bitcoin Wallet
# 23               Ethereum Wallet - ETH exchange
# 24                         D'CENT Crypto Wallet
# 25                    1inch: Wallet Crypto DeFi
# 26               Bitcoin Wallet Crypto Ethereum
# 27                imToken: Crypto & DeFi Wallet
# 28                    BlueWallet Bitcoin Wallet
# 29                        BRISE - Crypto Wallet
#
#                           developer  \
# 0                  BudgetBakers.com
# 1              DApps Platform, Inc.
# 2              MetaMask Web3 Wallet
# 3                       Airtm, Inc.
# 4                   Coinbase Wallet
# 5                BitKeep Global Inc
# 6                   WEMIX PTE. LTD.
# 7   PT. Nusa Satu Inti Artha (DOKU)
# 8                       Pera Wallet
# 9             Wallet Cards Alliance
# 10       Blockchain Luxembourg S.A.
# 11            Exodus Movement, Inc.
# 12                    KuCoin Wallet
# 13                        Soramitsu
# 14      Freewallet - Crypto Service
# 15                              ola
# 16           TokenPocket Foundation
# 17                        DeFi Labs
# 18                    Enjin PTE LTD
# 19      Freewallet - Crypto Service
# 20                   SafePal Wallet
# 21                      Bitcoin.com
# 22                          Coinomi
# 23      Freewallet - Crypto Service
# 24                 IoTrust Co., Ltd
# 25                 1inch Foundation
# 26                    Atomic Wallet
# 27                 IMTOKEN PTE.LTD.
# 28     BlueWallet Services S. R. L.
# 29              CRYPTOEXCHANGER LTD
#
#                                           description  dev_status
# 0   <b>Wallet membantu Anda merencanakan anggaran ...       False
# 1   Trust Wallet adalah dompet kripto resmi Binanc...       False
# 2   Whether you are an experienced user or brand n...       False
# 3   Mueve y usa tu dinero como y cuando quieras, e...       False
# 4   Coinbase Wallet adalah kunci Anda menuju hal b...       False
# 5   Didirikan di Singapura pada Mei 2018, BitKeep ...       False
# 6   <font color="#813ccc"><b>Integration with Vari...       False
# 7   DOKU, layanan dompet digital yang membantu sip...        True
# 8   Pera Algo Wallet is the simple, fast way to se...       False
# 9   Across all wallet apps on Play Store, \r\nWall...       False
# 10  Blockchain.com is the world's most trusted pla...       False
# 11  Buy, exchange, stake, and earn interest on cry...       False
# 12  KuCoin Wallet is the official crypto wallet of...       False
# 13  Fearless Wallet is designed for the decentrali...       False
# 14  Instal dompet Bitcoin Aman dari Freewallet dan...       False
# 15  Introducing the all new OLA Money wallet App!\...       False
# 16  TokenPocket is the leading multi-chain Crypto&...       False
# 17  Crypto.com DeFi Wallet is the best crypto wall...       False
# 18  <b>Dibuat untuk perdagangan kripto</b>\r\n\r\n...       False
# 19  Install Cryptocurrency Wallet yang transaksi d...       False
# 20  SafePal cryptocurrency wallet application - Yo...       False
# 21  Buy, sell, store, trade, and use cryptocurrenc...       False
# 22  <b>The blockchain wallet trusted by millions.<...       False
# 23  Menyimpan, mengirim, dan menerima ETH mengguna...       False
# 24  D'CENT Wallet memungkinkan Anda untuk menyimpa...       False
# 25  Wallet 1inch adalah wallet crypto non-kustodia...       False
# 26  Atomic Wallet is universal non-custodial app f...       False
# 27  imToken is your secure crypto and bitcoin wall...       False
# 28  A Bitcoin wallet that allows you to store, sen...       False
# 29  BRISE Wallet is the official crypto wallet of ...       False

# %% [markdown]
# ### Checking if the app is listed on the legal_PSP dataset
#
# After we check whether the developer is already listed on the legal_psp list or not, we need to further investigate if the product/app itself is already legally listed

# %% [markdown]
# We need to determine which method of Fuzzy String Matching best suited for the app name/title in our dataset.
#
# Based on the previous finding, we narrow it down to two method which are `token_sort_ratio` and `token_set_ratio`

# %%
listed_app = []
unlisted_app = []

# We settled using token_sort_ratio for a lot of app name are similar with each other
for app in result_df['title']:
    result = process.extractOne(app , legal_psp['product'], scorer = fuzz.token_sort_ratio)
    ratio = int(result[1])
    if ratio < 70:
         unlisted_app.append(app)
    else:
        listed_app.append(app)

# %%
# Sample of app that are listed in the legal_psp['product'] from the crawled dataset
listed_app[:5]
# Out:
# ['DOKU']

# %%
# Sample of developer that are NOT LISTED in the legal_psp['product'] from the crawled dataset
unlisted_developer[:5]
# Out:
# ['BudgetBakers.com',
#  'DApps Platform, Inc.',
#  'MetaMask Web3 Wallet',
#  'Airtm, Inc.',
#  'Coinbase Wallet']

# %%
# Create new column named 'app_status' where developer listed in listed_psp['product'] set as True
result_df['app_status'] = result_df['title'].isin(listed_app)

# %%
result_df
# Out:
#                                           title  \
# 0                     Wallet - Pelacak Anggaran
# 1                         Trust - Dompet Kripto
# 2                  MetaMask - Blockchain Wallet
# 3                                         Airtm
# 4                Coinbase Wallet: Simpan Kripto
# 5                   BitKeep: Dompet Crypto DeFi
# 6                                  WEMIX Wallet
# 7                                          DOKU
# 8                              Pera Algo Wallet
# 9                 Wallet Cards | Digital Wallet
# 10               Blockchain.com Wallet: Buy BTC
# 11                Exodus: Crypto Bitcoin Wallet
# 12                  KuCoin Wallet: Crypto & NFT
# 13               Fearless Wallet: Polkadot, クサマ
# 14               Dompet Bitcoin Aman Freewallet
# 15                  Ola Money - Wallet payments
# 16               TokenPocket Wallet Crypto DeFi
# 17                     Crypto.com l DeFi Wallet
# 18  Enjin: Bitcoin, Ethereum, Dompet Kripto NFT
# 19                  BTC & Altcoin crypto wallet
# 20               SafePal-Crypto wallet BTC NFTs
# 21               Bitcoin Wallet: BTC, ETH & BCH
# 22               Coinomi: Crypto Bitcoin Wallet
# 23               Ethereum Wallet - ETH exchange
# 24                         D'CENT Crypto Wallet
# 25                    1inch: Wallet Crypto DeFi
# 26               Bitcoin Wallet Crypto Ethereum
# 27                imToken: Crypto & DeFi Wallet
# 28                    BlueWallet Bitcoin Wallet
# 29                        BRISE - Crypto Wallet
#
#                           developer  \
# 0                  BudgetBakers.com
# 1              DApps Platform, Inc.
# 2              MetaMask Web3 Wallet
# 3                       Airtm, Inc.
# 4                   Coinbase Wallet
# 5                BitKeep Global Inc
# 6                   WEMIX PTE. LTD.
# 7   PT. Nusa Satu Inti Artha (DOKU)
# 8                       Pera Wallet
# 9             Wallet Cards Alliance
# 10       Blockchain Luxembourg S.A.
# 11            Exodus Movement, Inc.
# 12                    KuCoin Wallet
# 13                        Soramitsu
# 14      Freewallet - Crypto Service
# 15                              ola
# 16           TokenPocket Foundation
# 17                        DeFi Labs
# 18                    Enjin PTE LTD
# 19      Freewallet - Crypto Service
# 20                   SafePal Wallet
# 21                      Bitcoin.com
# 22                          Coinomi
# 23      Freewallet - Crypto Service
# 24                 IoTrust Co., Ltd
# 25                 1inch Foundation
# 26                    Atomic Wallet
# 27                 IMTOKEN PTE.LTD.
# 28     BlueWallet Services S. R. L.
# 29              CRYPTOEXCHANGER LTD
#
#                                           description  dev_status  app_status
# 0   <b>Wallet membantu Anda merencanakan anggaran ...       False       False
# 1   Trust Wallet adalah dompet kripto resmi Binanc...       False       False
# 2   Whether you are an experienced user or brand n...       False       False
# 3   Mueve y usa tu dinero como y cuando quieras, e...       False       False
# 4   Coinbase Wallet adalah kunci Anda menuju hal b...       False       False
# 5   Didirikan di Singapura pada Mei 2018, BitKeep ...       False       False
# 6   <font color="#813ccc"><b>Integration with Vari...       False       False
# 7   DOKU, layanan dompet digital yang membantu sip...        True        True
# 8   Pera Algo Wallet is the simple, fast way to se...       False       False
# 9   Across all wallet apps on Play Store, \r\nWall...       False       False
# 10  Blockchain.com is the world's most trusted pla...       False       False
# 11  Buy, exchange, stake, and earn interest on cry...       False       False
# 12  KuCoin Wallet is the official crypto wallet of...       False       False
# 13  Fearless Wallet is designed for the decentrali...       False       False
# 14  Instal dompet Bitcoin Aman dari Freewallet dan...       False       False
# 15  Introducing the all new OLA Money wallet App!\...       False       False
# 16  TokenPocket is the leading multi-chain Crypto&...       False       False
# 17  Crypto.com DeFi Wallet is the best crypto wall...       False       False
# 18  <b>Dibuat untuk perdagangan kripto</b>\r\n\r\n...       False       False
# 19  Install Cryptocurrency Wallet yang transaksi d...       False       False
# 20  SafePal cryptocurrency wallet application - Yo...       False       False
# 21  Buy, sell, store, trade, and use cryptocurrenc...       False       False
# 22  <b>The blockchain wallet trusted by millions.<...       False       False
# 23  Menyimpan, mengirim, dan menerima ETH mengguna...       False       False
# 24  D'CENT Wallet memungkinkan Anda untuk menyimpa...       False       False
# 25  Wallet 1inch adalah wallet crypto non-kustodia...       False       False
# 26  Atomic Wallet is universal non-custodial app f...       False       False
# 27  imToken is your secure crypto and bitcoin wall...       False       False
# 28  A Bitcoin wallet that allows you to store, sen...       False       False
# 29  BRISE Wallet is the official crypto wallet of ...       False       False

# %% [markdown]
# ### Final Result
#
# On the final step, we want to see the list of app that has potential to be furtherly investigated.
#
# Based on our method, we can categorize the list of app based on three different categories:
#    * Immediate Investigation = if the developer and app are set to false in the psp_legal dataset
#    * Further Checking = if one of the criteria set to false (developer OR app) in the psp_legal dataset
#    * Legally Listed = if both the developer and app are already listed in the psp_legal dataset
#
# *Do note that some of the application might listed on list of other regulatory organization (eg. OJK, Bappebti)*

# %% [markdown]
# #### Immediate Investigation:

# %%
print('List of app that needs immediate investigation are:' )
print('\n')
immediate_investigation = result_df.loc[(result_df['dev_status'] == False) & (result_df['app_status'] == False)]
print(immediate_investigation)
# Out:
# List of app that needs immediate investigation are:
#
#
#                                           title                     developer  \
# 0                     Wallet - Pelacak Anggaran              BudgetBakers.com
# 1                         Trust - Dompet Kripto          DApps Platform, Inc.
# 2                  MetaMask - Blockchain Wallet          MetaMask Web3 Wallet
# 3                                         Airtm                   Airtm, Inc.
# 4                Coinbase Wallet: Simpan Kripto               Coinbase Wallet
# 5                   BitKeep: Dompet Crypto DeFi            BitKeep Global Inc
# 6                                  WEMIX Wallet               WEMIX PTE. LTD.
# 8                              Pera Algo Wallet                   Pera Wallet
# 9                 Wallet Cards | Digital Wallet         Wallet Cards Alliance
# 10               Blockchain.com Wallet: Buy BTC    Blockchain Luxembourg S.A.
# 11                Exodus: Crypto Bitcoin Wallet         Exodus Movement, Inc.
# 12                  KuCoin Wallet: Crypto & NFT                 KuCoin Wallet
# 13               Fearless Wallet: Polkadot, クサマ                     Soramitsu
# 14               Dompet Bitcoin Aman Freewallet   Freewallet - Crypto Service
# 15                  Ola Money - Wallet payments                           ola
# 16               TokenPocket Wallet Crypto DeFi        TokenPocket Foundation
# 17                     Crypto.com l DeFi Wallet                     DeFi Labs
# 18  Enjin: Bitcoin, Ethereum, Dompet Kripto NFT                 Enjin PTE LTD
# 19                  BTC & Altcoin crypto wallet   Freewallet - Crypto Service
# 20               SafePal-Crypto wallet BTC NFTs                SafePal Wallet
# 21               Bitcoin Wallet: BTC, ETH & BCH                   Bitcoin.com
# 22               Coinomi: Crypto Bitcoin Wallet                       Coinomi
# 23               Ethereum Wallet - ETH exchange   Freewallet - Crypto Service
# 24                         D'CENT Crypto Wallet              IoTrust Co., Ltd
# 25                    1inch: Wallet Crypto DeFi              1inch Foundation
# 26               Bitcoin Wallet Crypto Ethereum                 Atomic Wallet
# 27                imToken: Crypto & DeFi Wallet              IMTOKEN PTE.LTD.
# 28                    BlueWallet Bitcoin Wallet  BlueWallet Services S. R. L.
# 29                        BRISE - Crypto Wallet           CRYPTOEXCHANGER LTD
#
#                                           description  dev_status  app_status
# 0   <b>Wallet membantu Anda merencanakan anggaran ...       False       False
# 1   Trust Wallet adalah dompet kripto resmi Binanc...       False       False
# 2   Whether you are an experienced user or brand n...       False       False
# 3   Mueve y usa tu dinero como y cuando quieras, e...       False       False
# 4   Coinbase Wallet adalah kunci Anda menuju hal b...       False       False
# 5   Didirikan di Singapura pada Mei 2018, BitKeep ...       False       False
# 6   <font color="#813ccc"><b>Integration with Vari...       False       False
# 8   Pera Algo Wallet is the simple, fast way to se...       False       False
# 9   Across all wallet apps on Play Store, \r\nWall...       False       False
# 10  Blockchain.com is the world's most trusted pla...       False       False
# 11  Buy, exchange, stake, and earn interest on cry...       False       False
# 12  KuCoin Wallet is the official crypto wallet of...       False       False
# 13  Fearless Wallet is designed for the decentrali...       False       False
# 14  Instal dompet Bitcoin Aman dari Freewallet dan...       False       False
# 15  Introducing the all new OLA Money wallet App!\...       False       False
# 16  TokenPocket is the leading multi-chain Crypto&...       False       False
# 17  Crypto.com DeFi Wallet is the best crypto wall...       False       False
# 18  <b>Dibuat untuk perdagangan kripto</b>\r\n\r\n...       False       False
# 19  Install Cryptocurrency Wallet yang transaksi d...       False       False
# 20  SafePal cryptocurrency wallet application - Yo...       False       False
# 21  Buy, sell, store, trade, and use cryptocurrenc...       False       False
# 22  <b>The blockchain wallet trusted by millions.<...       False       False
# 23  Menyimpan, mengirim, dan menerima ETH mengguna...       False       False
# 24  D'CENT Wallet memungkinkan Anda untuk menyimpa...       False       False
# 25  Wallet 1inch adalah wallet crypto non-kustodia...       False       False
# 26  Atomic Wallet is universal non-custodial app f...       False       False
# 27  imToken is your secure crypto and bitcoin wall...       False       False
# 28  A Bitcoin wallet that allows you to store, sen...       False       False
# 29  BRISE Wallet is the official crypto wallet of ...       False       False

# %% [markdown]
# #### Further Checking:

# %%
print('List of app that needs Further Checking are:' )
print('\n')
further_checking = result_df.loc[((result_df['dev_status'] == False) & (result_df['app_status'] == True) |
                                  (result_df['dev_status'] == True) & (result_df['app_status'] == False))]
print(further_checking)
# Out:
# List of app that needs Further Checking are:
#
#
# Empty DataFrame
# Columns: [title, developer, description, dev_status, app_status]
# Index: []

# %% [markdown]
# #### Legally Listed:

# %%
print('List of app that are legally listed are:' )
print('\n')
legally_listed = result_df.loc[(result_df['dev_status'] == True) & (result_df['app_status'] == True)]
print(legally_listed)
# Out:
# List of app that are legally listed are:
#
#
#   title                        developer  \
# 7  DOKU  PT. Nusa Satu Inti Artha (DOKU)
#
#                                          description  dev_status  app_status
# 7  DOKU, layanan dompet digital yang membantu sip...        True        True

# %% [markdown]
# ### Further Development
#
# There are several aspect that can be improved for further development which are:
#    * Data scraper needs to get more data of app listed in the playstore, passing the current limit of 30 apps data
#    * List of keywords used that are used to find payment related app
#    * Crosscheck with other list of legal app and organization that are listed on other regulator such as OJK and Bappebti
